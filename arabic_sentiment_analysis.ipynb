# %% [markdown]
# # Arabic Sentiment Analysis in tweets using Naive Bayes Machine learning Algorithm and unigram features

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import nltk
from nltk import NaiveBayesClassifier
from nltk.metrics.scores import f_measure, precision, recall
import collections
from builtins import chr
from nltk import word_tokenize, ngrams


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# Any results you write to the current directory are saved as output.

# %% [markdown]
# # define functions

# %%
import re
from itertools import islice
from nltk.corpus import stopwords
nltk.download('stopwords')



def arabicrange():
        """return a list of arabic characteres .
        Return a list of characteres between \u060c to \u0652
        @return: list of arabic characteres.
        @rtype: unicode;
        """
        mylist = [];
        for i in range(0x0620, 0x00650):
            try :
                mylist.append(chr(i));
            except ValueError:
                pass;
        return mylist[:-5]+[' '];

arb = arabicrange()
stopwords_list = stopwords.words('arabic')

def clean_raw_review(body):
        # return ''.join(c for c in body if c in arb)
        return ''.join(c if c in arb else ' ' for c in body)

         # patterns to remove first
        pat = [\
            (u'http[s]?://[a-zA-Z0-9_\-./~\?=%&]+', u''),  # remove links
            (u'www[a-zA-Z0-9_\-?=%&/.~]+', u''),
#            u'\n+': u' ',                     # remove newlines
            (u'<br />', u' '),  # remove html line breaks
            (u'</?[^>]+>', u' '),  # remove html markup
#            u'http': u'',
            (u'[a-zA-Z]+\.org', u''),
            (u'[a-zA-Z]+\.com', u''),
            (u'://', u''),
            (u'&[^;]+;', u' '),
            (u':D', u':)'),
#            (u'[0-9/]+', u''),
#            u'[a-zA-Z.]+': u'',
#            u'[^0-9' + u''.join(self.arabicrange()) + \
#                u"!.,;:$%&*%'#(){}~`\[\]/\\\\\"" + \
#                u'\s^><\-_\u201D\u00AB=\u2026]+': u'',          # remove latin characters
            (u'\s+', u' '),  # remove spaces
            (u'\.+', u'.'),  # multiple dots
            (u'[\u201C\u201D]', u'"'),  # “
            (u'[\u2665\u2764]', u''),  # heart symbol
            (u'[\u00BB\u00AB]', u'"'),
            (u'\u2013', u'-'),  # dash
        ]

        # patterns that disqualify a review
        remove_if_there = [\
            (u'[^0-9' + u''.join(arabicrange()) + \
                u"!.,;:$%&*%'#(){}~`\[\]/\\\\\"" + \
                u'\s\^><\-_\u201D\u00AB=\u2026+|' + \
                u'\u0660-\u066D\u201C\u201D' + \
                u'\ufefb\ufef7\ufef5\ufef9]+', u''),  # non arabic characters
        ]

        # patterns that disqualify if empty after removing
        remove_if_empty_after = [\
            (u'[0-9a-zA-Z\-_]', u' '),  # alpha-numeric
            (u'[0-9' + u".,!;:$%&*%'#(){}~`\[\]/\\\\\"" + \
                u'\s\^><`\-=_+]+', u''),  # remove just punctuation
            (u'\s+', u' '),  # remove spaces
        ]

        # remove again
        # patterns to remove
        pat2 = [\
#            u'[^0-9' + u''.join(self.arabicrange()) + \
#                u"!.,;:$%&*%'#(){}~`\[\]/\\\\\"" + \
#                u'\s^><\-_\u201D\u00AB=\u2026]+': u'',          # remove latin characters
        ]

        skip = False

        # if empty body, skip
        if body == u'': skip = True

        # do some subsitutions
        for k, v in pat:
            body = re.sub(k, v, body)

        # remove if exist
        for k, v in remove_if_there:
            if re.search(k, body):
                skip = True

        # remove if empty after replacing
        for k, v in remove_if_empty_after:
            temp = re.sub(k, v, body)
            if temp == u" " or temp == u"":
                skip = True

        # do some more subsitutions
        if not skip:
            for k, v in pat2:
                body = re.sub(k, v, body)

        # if empty string, skip
        if body == u'' or body == u' ':
            skip = True

        if not skip:
            return body
        else:
            return u""

def load_tsv(data_file, n):
    data_features = list()
    data = list()
    # infile = open(data_file, encoding='utf-8')

    infile = data_file.to_numpy()
    for line in infile:
        # if not line.strip():
        #     continue
        
        # text,label = line.split(',')
        text,label = line
        text = clean_raw_review(text)
        text_features = process_text(text, n)
        if text_features:
            text_features = [s for s in text_features if s and len(s)>1 and s not in stopwords_list]
            if not text_features:
              continue
            print(text_features)
            text_features = text_features +\
            rec_char_ngram(text_features,2)+\
            rec_char_ngram(text_features,3)+\
            rec_char_ngram(text_features,4)+\
            rec_char_ngram(text_features,5)+\

            data_features += text_features
            data.append((text_features, label))
        
    return data, data_features

def process_text(text, n=1,
                 remove_vowel_marks=False,
                 remove_repeated_chars=True,
                 ):
    clean_text = text
    # if remove_vowel_marks:
    #     clean_text = remove_diacritics(clean_text)
    if remove_repeated_chars:
        clean_text = remove_repeating_char(clean_text)

    if n == 1:
        return clean_text.split()
    else:
        tokens = clean_text.split()
        grams = tokens
        for i in range(2, n + 1):
            grams += [' '.join(g) for g in list(window(tokens, i))]

        return grams

def char_ngram(s, n):
  if len(s)>n:
    return [s[i:i+n] for i in range(len(s)-n+1)]
  else:
    return s

def rec_char_ngram(ls,n):
  ls = [i for i in ls if len(i)>n]
  return [j for jj in  [char_ngram(i,n) for i in ls] for j in jj]
    



def window(words_seq, n):
    """Returns a sliding window (of width n) over data from the iterable"""
    "   s -> (s0,s1,...s[n-1]), (s1,s2,...,sn), ...                   "
    it = iter(words_seq)
    result = tuple(islice(it, n))
    if len(result) == n:
        yield result
    for elem in it:
        result = result[1:] + (elem,)
        yield result


def remove_repeating_char(text):
    # return re.sub(r'(.)\1+', r'\1', text)     # keep only 1 repeat
    return re.sub(r'(.)\1+', r'\1\1', text)  # keep 2 repeat

def document_features(document, corpus_features):
    document_words = set(document)
    features = {}
    for word in corpus_features:
        features['has({})'.format(word)] = (word in document_words)
    return features
# Out:
#   File "<ipython-input-887-6a16be5246b5>", line 125
#     text_features = text_features +            rec_char_ngram(text_features,2)+            rec_char_ngram(text_features,3)+            rec_char_ngram(text_features,4)+            rec_char_ngram(text_features,5)+
#                                                                                                                                                                                                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Load corpus

# %%
for i in [1,2,4]:
  if True:
    continue
  print(i)

# %%
l = ['assds', 'asasdaads', 'asdaasd','jj']

# %%
rec_char_ngram(l,3)

# %%
char_ngram('as', 4)

# %%
''.join(('s','t'))

# %%
char_ngram("asaddddfgg",4)

# %%
char_ngram('student',3)

# %%
df = pd.read_csv('/content/CY_train.csv')
clean_raw_review(df.iloc[6,0])

# %%
# pos_train_file = '../input/train_Arabic_tweets_positive_20190413.tsv'
# neg_train_file = '../input/train_Arabic_tweets_negative_20190413.tsv'

# pos_test_file = '../input/test_Arabic_tweets_positive_20190413.tsv'
# neg_test_file = '../input/test_Arabic_tweets_negative_20190413.tsv'
# print('data files')
# print('train file (pos)', pos_train_file)
# print('train file (neg)', neg_train_file)
# print('test file (pos)', pos_test_file)
# print('test file (neg)', neg_test_file)

# %% [markdown]
# # Parameters (ngrams)

# %%
print('parameters')
n = 1
print('n grams:', n)

# %% [markdown]
# # loading train data ....

# %%
# print('loading train data ....')
# pos_train_data, pos_train_feat = load_tsv(pos_train_file, n)
# neg_train_data, neg_train_feat = load_tsv(neg_train_file, n)
# print('loading test data ....')
# pos_test_data, pos_test_feat = load_tsv(pos_test_file, n)
# neg_test_data, neg_test_feat = load_tsv(neg_test_file, n)

# %% [markdown]
# # Training data information

# %%
# print('train data info')
# train_data = pos_train_data + neg_train_data
# print('train data size', len(train_data))
# print('# of positive', len(pos_train_data))
# print('# of negative', len(neg_train_data))

# %%
# train_data,feat = load_tsv('/content/CY_train.csv', n)

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df,stratify=df['class'],test_size=0.2)

# %%
train['class'].value_counts()

# %%
test['class'].value_counts()

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
m = MultinomialNB()

# %%
train_data, train_feat = load_tsv(train,n)
test_data, test_feat = load_tsv(test,n)

# %%
test_data
# Out:
# [(['الافضل',
#    'ان',
#    'تعيش',
#    'حياتك',
#    'وتدعهم',
#    'يعيشوا',
#    'حياتهم',
#    'وعلي',
#    'قدر',
#    'اقترابهم',
#    'منك',
#    'اقترب',
#    'انت',
#    'واجعل',
#    'لمشاعرك',
#    'وزنا',
#    'تسريب',
#    'الشرق',
#    'لمكتب',
#    'السيسي',
#    'الا',
#    'لاف',
#    'افض',
#    'فضل',
#    'تعي',
#    'عيش',
#    'حيا',
#    'يات',
#    'اتك',
#    'وتد',
#    'تدع',
#    'دعه',
#    'عهم',
#    'يعي',
#    'عيش',
#    'يشو',
#    'شوا',
#    'حيا',
#    'يات',
#    'اته',
#    'تهم',
#    'وعل',
#    'علي',
#    'اقت',
#    'قتر',
#    'ترا',
#    'راب',
#    'ابه',
#    'بهم',
#    'اقت',
#    'قتر',
#    'ترب',
#    'واج',
#    'اجع',
#    'جعل',
#    'لمش',
#    'مشا',
#    'شاع',
#    'اعر',
#    'عرك',
#    'وزن',
#    'زنا',
#    'تسر',
#    'سري',
#    'ريب',
#    'الش',
#    'لشر',
#    'شرق',
#    'لمك',
#    'مكت',
#    'كتب',
#    'الس',
#    'لسي',
#    'سيس',
#    'يسي',
#    'الاف',
#    'لافض',
#    'افضل',
#    'حيات',
#    'ياتك',
#    'وتدع',
#    'تدعه',
#    'دعهم',
#    'يعيش',
#    'عيشو',
#    'يشوا',
#    'حيات',
#    'ياته',
#    'اتهم',
#    'اقتر',
#    'قترا',
#    'تراب',
#    'رابه',
#    'ابهم',
#    'اقتر',
#    'قترب',
#    'واجع',
#    'اجعل',
#    'لمشا',
#    'مشاع',
#    'شاعر',
#    'اعرك',
#    'تسري',
#    'سريب',
#    'الشر',
#    'لشرق',
#    'لمكت',
#    'مكتب',
#    'السي',
#    'لسيس',
#    'سيسي',
#    'ال',
#    'لا',
#    'اف',
#    'فض',
#    'ضل',
#    'تع',
#    'عي',
#    'يش',
#    'حي',
#    'يا',
#    'ات',
#    'تك',
#    'وت',
#    'تد',
#    'دع',
#    'عه',
#    'هم',
#    'يع',
#    'عي',
#    'يش',
#    'شو',
#    'وا',
#    'حي',
#    'يا',
#    'ات',
#    'ته',
#    'هم',
#    'وع',
#    'عل',
#    'لي',
#    'قد',
#    'در',
#    'اق',
#    'قت',
#    'تر',
#    'را',
#    'اب',
#    'به',
#    'هم',
#    'من',
#    'نك',
#    'اق',
#    'قت',
#    'تر',
#    'رب',
#    'ان',
#    'نت',
#    'وا',
#    'اج',
#    'جع',
#    'عل',
#    'لم',
#    'مش',
#    'شا',
#    'اع',
#    'عر',
#    'رك',
#    'وز',
#    'زن',
#    'نا',
#    'تس',
#    'سر',
#    'ري',
#    'يب',
#    'ال',
#    'لش',
#    'شر',
#    'رق',
#    'لم',
#    'مك',
#    'كت',
#    'تب',
#    'ال',
#    'لس',
#    'سي',
#    'يس',
#    'سي'],
#   'neu'),
#  (['ان', 'الص', 'اح', 'الم', 'وت', 'حن', 'ال', 'لص', 'ال', 'لم'], 'neg'),
#  (['مالها',
#    'أمي',
#    'يابن',
#    'المرة',
#    'مال',
#    'اله',
#    'لها',
#    'ياب',
#    'ابن',
#    'الم',
#    'لمر',
#    'مرة',
#    'ماله',
#    'الها',
#    'المر',
#    'لمرة',
#    'ما',
#    'ال',
#    'له',
#    'ها',
#    'أم',
#    'مي',
#    'يا',
#    'اب',
#    'بن',
#    'ال',
#    'لم',
#    'مر',
#    'رة'],
#   'neg'),
#  (['يصير',
#    'يصير',
#    'مش',
#    'يقولوا',
#    'انه',
#    'الاموات',
#    'يسمعوا',
#    'فينا',
#    'يصي',
#    'صير',
#    'يصي',
#    'صير',
#    'يقو',
#    'قول',
#    'ولو',
#    'لوا',
#    'الا',
#    'لام',
#    'امو',
#    'موا',
#    'وات',
#    'يسم',
#    'سمع',
#    'معو',
#    'عوا',
#    'فين',
#    'ينا',
#    'يقول',
#    'قولو',
#    'ولوا',
#    'الام',
#    'لامو',
#    'اموا',
#    'موات',
#    'يسمع',
#    'سمعو',
#    'معوا',
#    'يص',
#    'صي',
#    'ير',
#    'يص',
#    'صي',
#    'ير',
#    'يق',
#    'قو',
#    'ول',
#    'لو',
#    'وا',
#    'ان',
#    'نه',
#    'ال',
#    'لا',
#    'ام',
#    'مو',
#    'وا',
#    'ات',
#    'يس',
#    'سم',
#    'مع',
#    'عو',
#    'وا',
#    'في',
#    'ين',
#    'نا'],
#   'neu'),
#  (['تيديش',
#    'حد',
#    'اكبر',
#    'حجمه',
#    'ترجع',
#    'تزعل',
#    'تيد',
#    'يدي',
#    'ديش',
#    'اكب',
#    'كبر',
#    'حجم',
#    'جمه',
#    'ترج',
#    'رجع',
#    'تزع',
#    'زعل',
#    'تيدي',
#    'يديش',
#    'تي',
#    'يد',
#    'دي',
#    'يش',
#    'اك',
#    'كب',
#    'بر',
#    'حج',
#    'جم',
#    'مه',
#    'تر',
#    'رج',
#    'جع',
#    'تز',
#    'زع',
#    'عل'],
#   'neu'),
#  (['كله',
#    'هري',
#    'بليل',
#    'هيبان',
#    'حاجه',
#    'بلي',
#    'ليل',
#    'هيب',
#    'يبا',
#    'بان',
#    'حاج',
#    'اجه',
#    'هيبا',
#    'يبان',
#    'كل',
#    'له',
#    'هر',
#    'ري',
#    'بل',
#    'لي',
#    'يل',
#    'هي',
#    'يب',
#    'با',
#    'ان',
#    'حا',
#    'اج',
#    'جه'],
#   'neu'),
#  (['أحمد',
#    'حلمي',
#    'إنسان',
#    'جميل',
#    'جدا',
#    'عبقري',
#    'أسطورة',
#    'نفسه',
#    'كده',
#    'أحم',
#    'حمد',
#    'حلم',
#    'لمي',
#    'إنس',
#    'نسا',
#    'سان',
#    'جمي',
#    'ميل',
#    'عبق',
#    'بقر',
#    'قري',
#    'أسط',
#    'سطو',
#    'طور',
#    'ورة',
#    'نفس',
#    'فسه',
#    'إنسا',
#    'نسان',
#    'عبقر',
#    'بقري',
#    'أسطو',
#    'سطور',
#    'طورة',
#    'أح',
#    'حم',
#    'مد',
#    'حل',
#    'لم',
#    'مي',
#    'إن',
#    'نس',
#    'سا',
#    'ان',
#    'جم',
#    'مي',
#    'يل',
#    'جد',
#    'دا',
#    'عب',
#    'بق',
#    'قر',
#    'ري',
#    'أس',
#    'سط',
#    'طو',
#    'ور',
#    'رة',
#    'نف',
#    'فس',
#    'سه',
#    'كد',
#    'ده'],
#   'pos'),
#  (['قائمة',
#    'الشخصيات',
#    'الأكثر',
#    'تأثيرا',
#    'وسائل',
#    'التواصل',
#    'الاجتماعي',
#    'الثامن',
#    'الاردن',
#    'قائ',
#    'ائم',
#    'ئمة',
#    'الش',
#    'لشخ',
#    'شخص',
#    'خصي',
#    'صيا',
#    'يات',
#    'الأ',
#    'لأك',
#    'أكث',
#    'كثر',
#    'تأث',
#    'أثي',
#    'ثير',
#    'يرا',
#    'وسا',
#    'سائ',
#    'ائل',
#    'الت',
#    'لتو',
#    'توا',
#    'واص',
#    'اصل',
#    'الا',
#    'لاج',
#    'اجت',
#    'جتم',
#    'تما',
#    'ماع',
#    'اعي',
#    'الث',
#    'لثا',
#    'ثام',
#    'امن',
#    'الا',
#    'لار',
#    'ارد',
#    'ردن',
#    'قائم',
#    'ائمة',
#    'الشخ',
#    'لشخص',
#    'شخصي',
#    'خصيا',
#    'صيات',
#    'الأك',
#    'لأكث',
#    'أكثر',
#    'تأثي',
#    'أثير',
#    'ثيرا',
#    'وسائ',
#    'سائل',
#    'التو',
#    'لتوا',
#    'تواص',
#    'واصل',
#    'الاج',
#    'لاجت',
#    'اجتم',
#    'جتما',
#    'تماع',
#    'ماعي',
#    'الثا',
#    'لثام',
#    'ثامن',
#    'الار',
#    'لارد',
#    'اردن',
#    'قا',
#    'ائ',
#    'ئم',
#    'مة',
#    'ال',
#    'لش',
#    'شخ',
#    'خص',
#    'صي',
#    'يا',
#    'ات',
#    'ال',
#    'لأ',
#    'أك',
#    'كث',
#    'ثر',
#    'تأ',
#    'أث',
#    'ثي',
#    'ير',
#    'را',
#    'وس',
#    'سا',
#    'ائ',
#    'ئل',
#    'ال',
#    'لت',
#    'تو',
#    'وا',
#    'اص',
#    'صل',
#    'ال',
#    'لا',
#    'اج',
#    'جت',
#    'تم',
#    'ما',
#    'اع',
#    'عي',
#    'ال',
#    'لث',
#    'ثا',
#    'ام',
#    'من',
#    'ال',
#    'لا',
#    'ار',
#    'رد',
#    'دن'],
#   'neu'),
#  (['تشكيل',
#    'الأهلى',
#    'مسعد',
#    'شريف',
#    'عبدالفضيل',
#    'سعد',
#    'شريف',
#    'حازم',
#    'لؤى',
#    'وائل',
#    'غالى',
#    'السعيد',
#    'سليمان',
#    'تريزجيه',
#    'متعب',
#    'تشك',
#    'شكي',
#    'كيل',
#    'الأ',
#    'لأه',
#    'أهل',
#    'هلى',
#    'مسع',
#    'سعد',
#    'شري',
#    'ريف',
#    'عبد',
#    'بدا',
#    'دال',
#    'الف',
#    'لفض',
#    'فضي',
#    'ضيل',
#    'شري',
#    'ريف',
#    'حاز',
#    'ازم',
#    'وائ',
#    'ائل',
#    'غال',
#    'الى',
#    'الس',
#    'لسع',
#    'سعي',
#    'عيد',
#    'سلي',
#    'ليم',
#    'يما',
#    'مان',
#    'تري',
#    'ريز',
#    'يزج',
#    'زجي',
#    'جيه',
#    'متع',
#    'تعب',
#    'تشكي',
#    'شكيل',
#    'الأه',
#    'لأهل',
#    'أهلى',
#    'عبدا',
#    'بدال',
#    'دالف',
#    'الفض',
#    'لفضي',
#    'فضيل',
#    'السع',
#    'لسعي',
#    'سعيد',
#    'سليم',
#    'ليما',
#    'يمان',
#    'تريز',
#    'ريزج',
#    'يزجي',
#    'زجيه',
#    'تش',
#    'شك',
#    'كي',
#    'يل',
#    'ال',
#    'لأ',
#    'أه',
#    'هل',
#    'لى',
#    'مس',
#    'سع',
#    'عد',
#    'شر',
#    'ري',
#    'يف',
#    'عب',
#    'بد',
#    'دا',
#    'ال',
#    'لف',
#    'فض',
#    'ضي',
#    'يل',
#    'سع',
#    'عد',
#    'شر',
#    'ري',
#    'يف',
#    'حا',
#    'از',
#    'زم',
#    'لؤ',
#    'ؤى',
#    'وا',
#    'ائ',
#    'ئل',
#    'غا',
#    'ال',
#    'لى',
#    'ال',
#    'لس',
#    'سع',
#    'عي',
#    'يد',
#    'سل',
#    'لي',
#    'يم',
#    'ما',
#    'ان',
#    'تر',
#    'ري',
#    'يز',
#    'زج',
#    'جي',
#    'يه',
#    'مت',
#    'تع',
#    'عب'],
#   'neu'),
#  (['روعه',
#    'غاية',
#    'التعبير',
#    'روع',
#    'وعه',
#    'غاي',
#    'اية',
#    'الت',
#    'لتع',
#    'تعب',
#    'عبي',
#    'بير',
#    'التع',
#    'لتعب',
#    'تعبي',
#    'عبير',
#    'رو',
#    'وع',
#    'عه',
#    'غا',
#    'اي',
#    'ية',
#    'ال',
#    'لت',
#    'تع',
#    'عب',
#    'بي',
#    'ير'],
#   'pos'),
#  (['فقدنا',
#    'فيك',
#    'الأمل',
#    'مفيش',
#    'منك',
#    'رجا',
#    'رمينا',
#    'طوبتك',
#    'زمان',
#    'فقد',
#    'قدن',
#    'دنا',
#    'الأ',
#    'لأم',
#    'أمل',
#    'مفي',
#    'فيش',
#    'رمي',
#    'مين',
#    'ينا',
#    'طوب',
#    'وبت',
#    'بتك',
#    'زما',
#    'مان',
#    'فقدن',
#    'قدنا',
#    'الأم',
#    'لأمل',
#    'رمين',
#    'مينا',
#    'طوبت',
#    'وبتك',
#    'فق',
#    'قد',
#    'دن',
#    'نا',
#    'في',
#    'يك',
#    'ال',
#    'لأ',
#    'أم',
#    'مل',
#    'مف',
#    'في',
#    'يش',
#    'من',
#    'نك',
#    'رج',
#    'جا',
#    'رم',
#    'مي',
#    'ين',
#    'نا',
#    'طو',
#    'وب',
#    'بت',
#    'تك',
#    'زم',
#    'ما',
#    'ان'],
#   'neg'),
#  (['والناس',
#    'بقت',
#    'غريبة',
#    'أكتر',
#    'وائل',
#    'جسار',
#    'متخيل',
#    'وال',
#    'الن',
#    'لنا',
#    'ناس',
#    'غري',
#    'ريب',
#    'يبة',
#    'أكت',
#    'كتر',
#    'وائ',
#    'ائل',
#    'جسا',
#    'سار',
#    'متخ',
#    'تخي',
#    'خيل',
#    'والن',
#    'النا',
#    'لناس',
#    'غريب',
#    'ريبة',
#    'متخي',
#    'تخيل',
#    'وا',
#    'ال',
#    'لن',
#    'نا',
#    'اس',
#    'بق',
#    'قت',
#    'غر',
#    'ري',
#    'يب',
#    'بة',
#    'أك',
#    'كت',
#    'تر',
#    'وا',
#    'ائ',
#    'ئل',
#    'جس',
#    'سا',
#    'ار',
#    'مت',
#    'تخ',
#    'خي',
#    'يل'],
#   'neu'),
#  (['الخير',
#    'اصبحنا',
#    'واصبح',
#    'الملك',
#    'لله',
#    'اللهم',
#    'إهدينا',
#    'وإجمعنا',
#    'كلمة',
#    'حق',
#    'فى',
#    'الصباح',
#    'الفتاح',
#    'امين',
#    'الخ',
#    'لخي',
#    'خير',
#    'اصب',
#    'صبح',
#    'بحن',
#    'حنا',
#    'واص',
#    'اصب',
#    'صبح',
#    'الم',
#    'لمل',
#    'ملك',
#    'الل',
#    'لله',
#    'لهم',
#    'إهد',
#    'هدي',
#    'دين',
#    'ينا',
#    'وإج',
#    'إجم',
#    'جمع',
#    'معن',
#    'عنا',
#    'كلم',
#    'لمة',
#    'الص',
#    'لصب',
#    'صبا',
#    'باح',
#    'الف',
#    'لفت',
#    'فتا',
#    'تاح',
#    'امي',
#    'مين',
#    'الخي',
#    'لخير',
#    'اصبح',
#    'صبحن',
#    'بحنا',
#    'واصب',
#    'اصبح',
#    'المل',
#    'لملك',
#    'الله',
#    'للهم',
#    'إهدي',
#    'هدين',
#    'دينا',
#    'وإجم',
#    'إجمع',
#    'جمعن',
#    'معنا',
#    'الصب',
#    'لصبا',
#    'صباح',
#    'الفت',
#    'لفتا',
#    'فتاح',
#    'ال',
#    'لخ',
#    'خي',
#    'ير',
#    'اص',
#    'صب',
#    'بح',
#    'حن',
#    'نا',
#    'وا',
#    'اص',
#    'صب',
#    'بح',
#    'ال',
#    'لم',
#    'مل',
#    'لك',
#    'لل',
#    'له',
#    'ال',
#    'لل',
#    'له',
#    'هم',
#    'إه',
#    'هد',
#    'دي',
#    'ين',
#    'نا',
#    'وإ',
#    'إج',
#    'جم',
#    'مع',
#    'عن',
#    'نا',
#    'كل',
#    'لم',
#    'مة',
#    'ال',
#    'لص',
#    'صب',
#    'با',
#    'اح',
#    'ال',
#    'لف',
#    'فت',
#    'تا',
#    'اح',
#    'ام',
#    'مي',
#    'ين'],
#   'neu'),
#  (['المصري',
#    'اليوم',
#    'ناعوت',
#    'أذيال',
#    'الإخوان',
#    'وراء',
#    'اتهامي',
#    'بازدراء',
#    'الإسلام',
#    'أتبرأ',
#    'كتبت',
#    'الم',
#    'لمص',
#    'مصر',
#    'صري',
#    'الي',
#    'ليو',
#    'يوم',
#    'ناع',
#    'اعو',
#    'عوت',
#    'أذي',
#    'ذيا',
#    'يال',
#    'الإ',
#    'لإخ',
#    'إخو',
#    'خوا',
#    'وان',
#    'ورا',
#    'راء',
#    'اته',
#    'تها',
#    'هام',
#    'امي',
#    'باز',
#    'ازد',
#    'زدر',
#    'درا',
#    'راء',
#    'الإ',
#    'لإس',
#    'إسل',
#    'سلا',
#    'لام',
#    'أتب',
#    'تبر',
#    'برأ',
#    'كتب',
#    'تبت',
#    'المص',
#    'لمصر',
#    'مصري',
#    'اليو',
#    'ليوم',
#    'ناعو',
#    'اعوت',
#    'أذيا',
#    'ذيال',
#    'الإخ',
#    'لإخو',
#    'إخوا',
#    'خوان',
#    'اتها',
#    'تهام',
#    'هامي',
#    'بازد',
#    'ازدر',
#    'زدرا',
#    'دراء',
#    'الإس',
#    'لإسل',
#    'إسلا',
#    'سلام',
#    'أتبر',
#    'تبرأ',
#    'ال',
#    'لم',
#    'مص',
#    'صر',
#    'ري',
#    'ال',
#    'لي',
#    'يو',
#    'وم',
#    'نا',
#    'اع',
#    'عو',
#    'وت',
#    'أذ',
#    'ذي',
#    'يا',
#    'ال',
#    'ال',
#    'لإ',
#    'إخ',
#    'خو',
#    'وا',
#    'ان',
#    'ور',
#    'را',
#    'اء',
#    'ات',
#    'ته',
#    'ها',
#    'ام',
#    'مي',
#    'با',
#    'از',
#    'زد',
#    'در',
#    'را',
#    'اء',
#    'ال',
#    'لإ',
#    'إس',
#    'سل',
#    'لا',
#    'ام',
#    'أت',
#    'تب',
#    'بر',
#    'رأ',
#    'كت',
#    'تب',
#    'بت'],
#   'neu'),
#  (['اوحش',
#    'حاجة',
#    'الدنيا',
#    'تبقي',
#    'عايش',
#    'انت',
#    'مش',
#    'عارف',
#    'انت',
#    'عايش',
#    'علشان',
#    'اية',
#    'ملكش',
#    'هدف',
#    'اوح',
#    'وحش',
#    'حاج',
#    'اجة',
#    'الد',
#    'لدن',
#    'دني',
#    'نيا',
#    'تبق',
#    'بقي',
#    'عاي',
#    'ايش',
#    'عار',
#    'ارف',
#    'عاي',
#    'ايش',
#    'علش',
#    'لشا',
#    'شان',
#    'ملك',
#    'لكش',
#    'الدن',
#    'لدني',
#    'دنيا',
#    'علشا',
#    'لشان',
#    'او',
#    'وح',
#    'حش',
#    'حا',
#    'اج',
#    'جة',
#    'ال',
#    'لد',
#    'دن',
#    'ني',
#    'يا',
#    'تب',
#    'بق',
#    'قي',
#    'عا',
#    'اي',
#    'يش',
#    'ان',
#    'نت',
#    'عا',
#    'ار',
#    'رف',
#    'ان',
#    'نت',
#    'عا',
#    'اي',
#    'يش',
#    'عل',
#    'لش',
#    'شا',
#    'ان',
#    'اي',
#    'ية',
#    'مل',
#    'لك',
#    'كش',
#    'هد',
#    'دف'],
#   'neg'),
#  (['دة',
#    'انت',
#    'الحلم',
#    'اللى',
#    'نفسي',
#    'يكمل',
#    'يبقى',
#    'حقيقة',
#    'الح',
#    'لحل',
#    'حلم',
#    'الل',
#    'للى',
#    'نفس',
#    'فسي',
#    'يكم',
#    'كمل',
#    'يبق',
#    'بقى',
#    'حقي',
#    'قيق',
#    'يقة',
#    'الحل',
#    'لحلم',
#    'حقيق',
#    'قيقة',
#    'ان',
#    'نت',
#    'ال',
#    'لح',
#    'حل',
#    'لم',
#    'ال',
#    'لل',
#    'لى',
#    'نف',
#    'فس',
#    'سي',
#    'يك',
#    'كم',
#    'مل',
#    'يب',
#    'بق',
#    'قى',
#    'حق',
#    'قي',
#    'يق',
#    'قة'],
#   'pos'),
#  (['تفالوو',
#    'خيرر',
#    'للقب',
#    'لابن',
#    'مصر',
#    'باذن',
#    'الله',
#    'تفا',
#    'فال',
#    'الو',
#    'لوو',
#    'خير',
#    'يرر',
#    'للق',
#    'لقب',
#    'لاب',
#    'ابن',
#    'باذ',
#    'اذن',
#    'الل',
#    'لله',
#    'تفال',
#    'فالو',
#    'الوو',
#    'تف',
#    'فا',
#    'ال',
#    'لو',
#    'وو',
#    'خي',
#    'ير',
#    'رر',
#    'لل',
#    'لق',
#    'قب',
#    'لا',
#    'اب',
#    'بن',
#    'مص',
#    'صر',
#    'با',
#    'اذ',
#    'ذن',
#    'ال',
#    'لل',
#    'له'],
#   'pos'),
#  (['شي',
#    'جديد',
#    'أعمارنا',
#    'تزيد',
#    'ولازلنا',
#    'حق',
#    'ربنا',
#    'قص',
#    'رين',
#    'جدي',
#    'ديد',
#    'أعم',
#    'عما',
#    'مار',
#    'ارن',
#    'رنا',
#    'تزي',
#    'زيد',
#    'ولا',
#    'لاز',
#    'ازل',
#    'زلن',
#    'لنا',
#    'ربن',
#    'بنا',
#    'أعما',
#    'عمار',
#    'مارن',
#    'ارنا',
#    'ولاز',
#    'لازل',
#    'ازلن',
#    'زلنا',
#    'جد',
#    'دي',
#    'يد',
#    'أع',
#    'عم',
#    'ما',
#    'ار',
#    'رن',
#    'نا',
#    'تز',
#    'زي',
#    'يد',
#    'ول',
#    'لا',
#    'از',
#    'زل',
#    'لن',
#    'نا',
#    'رب',
#    'بن',
#    'نا',
#    'ري',
#    'ين'],
#   'neg'),
#  (['وفد',
#    'اتحاد',
#    'الغرف',
#    'العربية',
#    'زار',
#    'غرفة',
#    'الشمال',
#    'وتأكيد',
#    'توثيق',
#    'الروابط',
#    'المحكمة',
#    'الجانبين',
#    'اتح',
#    'تحا',
#    'حاد',
#    'الغ',
#    'لغر',
#    'غرف',
#    'الع',
#    'لعر',
#    'عرب',
#    'ربي',
#    'بية',
#    'غرف',
#    'رفة',
#    'الش',
#    'لشم',
#    'شما',
#    'مال',
#    'وتأ',
#    'تأك',
#    'أكي',
#    'كيد',
#    'توث',
#    'وثي',
#    'ثيق',
#    'الر',
#    'لرو',
#    'روا',
#    'واب',
#    'ابط',
#    'الم',
#    'لمح',
#    'محك',
#    'حكم',
#    'كمة',
#    'الج',
#    'لجا',
#    'جان',
#    'انب',
#    'نبي',
#    'بين',
#    'اتحا',
#    'تحاد',
#    'الغر',
#    'لغرف',
#    'العر',
#    'لعرب',
#    'عربي',
#    'ربية',
#    'الشم',
#    'لشما',
#    'شمال',
#    'وتأك',
#    'تأكي',
#    'أكيد',
#    'توثي',
#    'وثيق',
#    'الرو',
#    'لروا',
#    'رواب',
#    'وابط',
#    'المح',
#    'لمحك',
#    'محكم',
#    'حكمة',
#    'الجا',
#    'لجان',
#    'جانب',
#    'انبي',
#    'نبين',
#    'وف',
#    'فد',
#    'ات',
#    'تح',
#    'حا',
#    'اد',
#    'ال',
#    'لغ',
#    'غر',
#    'رف',
#    'ال',
#    'لع',
#    'عر',
#    'رب',
#    'بي',
#    'ية',
#    'زا',
#    'ار',
#    'غر',
#    'رف',
#    'فة',
#    'ال',
#    'لش',
#    'شم',
#    'ما',
#    'ال',
#    'وت',
#    'تأ',
#    'أك',
#    'كي',
#    'يد',
#    'تو',
#    'وث',
#    'ثي',
#    'يق',
#    'ال',
#    'لر',
#    'رو',
#    'وا',
#    'اب',
#    'بط',
#    'ال',
#    'لم',
#    'مح',
#    'حك',
#    'كم',
#    'مة',
#    'ال',
#    'لج',
#    'جا',
#    'ان',
#    'نب',
#    'بي',
#    'ين'],
#   'neu'),
#  (['احلا',
#    'عملاقه',
#    'احل',
#    'حلا',
#    'عمل',
#    'ملا',
#    'لاق',
#    'اقه',
#    'عملا',
#    'ملاق',
#    'لاقه',
#    'اح',
#    'حل',
#    'لا',
#    'عم',
#    'مل',
#    'لا',
#    'اق',
#    'قه'],
#   'pos'),
#  (['شهوة',
#    'الجوع',
#    'تتغلب',
#    'احيانا',
#    'الشهوه',
#    'الجنسيه',
#    'شهو',
#    'هوة',
#    'الج',
#    'لجو',
#    'جوع',
#    'تتغ',
#    'تغل',
#    'غلب',
#    'احي',
#    'حيا',
#    'يان',
#    'انا',
#    'الش',
#    'لشه',
#    'شهو',
#    'هوه',
#    'الج',
#    'لجن',
#    'جنس',
#    'نسي',
#    'سيه',
#    'الجو',
#    'لجوع',
#    'تتغل',
#    'تغلب',
#    'احيا',
#    'حيان',
#    'يانا',
#    'الشه',
#    'لشهو',
#    'شهوه',
#    'الجن',
#    'لجنس',
#    'جنسي',
#    'نسيه',
#    'شه',
#    'هو',
#    'وة',
#    'ال',
#    'لج',
#    'جو',
#    'وع',
#    'تت',
#    'تغ',
#    'غل',
#    'لب',
#    'اح',
#    'حي',
#    'يا',
#    'ان',
#    'نا',
#    'ال',
#    'لش',
#    'شه',
#    'هو',
#    'وه',
#    'ال',
#    'لج',
#    'جن',
#    'نس',
#    'سي',
#    'يه'],
#   'neu'),
#  (['ريتاج',
#    'وحشتنى',
#    'قمر',
#    'انا',
#    'زنيب',
#    'يلدريم',
#    'علشان',
#    'عيونك',
#    'حلوة',
#    'حياتى',
#    'ذاد',
#    'حلاوة',
#    'فيهم',
#    'ريت',
#    'يتا',
#    'تاج',
#    'وحش',
#    'حشت',
#    'شتن',
#    'تنى',
#    'زني',
#    'نيب',
#    'يلد',
#    'لدر',
#    'دري',
#    'ريم',
#    'علش',
#    'لشا',
#    'شان',
#    'عيو',
#    'يون',
#    'ونك',
#    'حلو',
#    'لوة',
#    'حيا',
#    'يات',
#    'اتى',
#    'حلا',
#    'لاو',
#    'اوة',
#    'فيه',
#    'يهم',
#    'ريتا',
#    'يتاج',
#    'وحشت',
#    'حشتن',
#    'شتنى',
#    'يلدر',
#    'لدري',
#    'دريم',
#    'علشا',
#    'لشان',
#    'عيون',
#    'يونك',
#    'حيات',
#    'ياتى',
#    'حلاو',
#    'لاوة',
#    'ري',
#    'يت',
#    'تا',
#    'اج',
#    'وح',
#    'حش',
#    'شت',
#    'تن',
#    'نى',
#    'قم',
#    'مر',
#    'ان',
#    'نا',
#    'زن',
#    'ني',
#    'يب',
#    'يل',
#    'لد',
#    'در',
#    'ري',
#    'يم',
#    'عل',
#    'لش',
#    'شا',
#    'ان',
#    'عي',
#    'يو',
#    'ون',
#    'نك',
#    'حل',
#    'لو',
#    'وة',
#    'حي',
#    'يا',
#    'ات',
#    'تى',
#    'ذا',
#    'اد',
#    'حل',
#    'لا',
#    'او',
#    'وة',
#    'في',
#    'يه',
#    'هم'],
#   'pos'),
#  (['انا',
#    'ولد',
#    'بنعازي',
#    'يكفيني',
#    'عارف',
#    'الصح',
#    'الخطاء',
#    'وعارف',
#    'امعمر',
#    'الحقير',
#    'انه',
#    'عافس',
#    'الحقراء',
#    'اللي',
#    'الليثي',
#    'بنع',
#    'نعا',
#    'عاز',
#    'ازي',
#    'يكف',
#    'كفي',
#    'فين',
#    'يني',
#    'عار',
#    'ارف',
#    'الص',
#    'لصح',
#    'الخ',
#    'لخط',
#    'خطا',
#    'طاء',
#    'وعا',
#    'عار',
#    'ارف',
#    'امع',
#    'معم',
#    'عمر',
#    'الح',
#    'لحق',
#    'حقي',
#    'قير',
#    'عاف',
#    'افس',
#    'الح',
#    'لحق',
#    'حقر',
#    'قرا',
#    'راء',
#    'الل',
#    'للي',
#    'الل',
#    'للي',
#    'ليث',
#    'يثي',
#    'بنعا',
#    'نعاز',
#    'عازي',
#    'يكفي',
#    'كفين',
#    'فيني',
#    'الخط',
#    'لخطا',
#    'خطاء',
#    'وعار',
#    'عارف',
#    'امعم',
#    'معمر',
#    'الحق',
#    'لحقي',
#    'حقير',
#    'الحق',
#    'لحقر',
#    'حقرا',
#    'قراء',
#    'اللي',
#    'لليث',
#    'ليثي',
#    'ان',
#    'نا',
#    'ول',
#    'لد',
#    'بن',
#    'نع',
#    'عا',
#    'از',
#    'زي',
#    'يك',
#    'كف',
#    'في',
#    'ين',
#    'ني',
#    'عا',
#    'ار',
#    'رف',
#    'ال',
#    'لص',
#    'صح',
#    'ال',
#    'لخ',
#    'خط',
#    'طا',
#    'اء',
#    'وع',
#    'عا',
#    'ار',
#    'رف',
#    'ام',
#    'مع',
#    'عم',
#    'مر',
#    'ال',
#    'لح',
#    'حق',
#    'قي',
#    'ير',
#    'ان',
#    'نه',
#    'عا',
#    'اف',
#    'فس',
#    'ال',
#    'لح',
#    'حق',
#    'قر',
#    'را',
#    'اء',
#    'ال',
#    'لل',
#    'لي',
#    'ال',
#    'لل',
#    'لي',
#    'يث',
#    'ثي'],
#   'neg'),
#  (['الصراحه',
#    'انا',
#    'مش',
#    'عارفه',
#    'اتعاطف',
#    'معاها',
#    'هى',
#    'دلعها',
#    'انانيتها',
#    'اللى',
#    'وصلوها',
#    'لكده',
#    'شغله',
#    'لازم',
#    'يستنى',
#    'عشان',
#    'خاطرها',
#    'الص',
#    'لصر',
#    'صرا',
#    'راح',
#    'احه',
#    'عار',
#    'ارف',
#    'رفه',
#    'اتع',
#    'تعا',
#    'عاط',
#    'اطف',
#    'معا',
#    'عاه',
#    'اها',
#    'دلع',
#    'لعه',
#    'عها',
#    'انا',
#    'نان',
#    'اني',
#    'نيت',
#    'يته',
#    'تها',
#    'الل',
#    'للى',
#    'وصل',
#    'صلو',
#    'لوه',
#    'وها',
#    'لكد',
#    'كده',
#    'شغل',
#    'غله',
#    'لاز',
#    'ازم',
#    'يست',
#    'ستن',
#    'تنى',
#    'عشا',
#    'شان',
#    'خاط',
#    'اطر',
#    'طره',
#    'رها',
#    'الصر',
#    'لصرا',
#    'صراح',
#    'راحه',
#    'عارف',
#    'ارفه',
#    'اتعا',
#    'تعاط',
#    'عاطف',
#    'معاه',
#    'عاها',
#    'دلعه',
#    'لعها',
#    'انان',
#    'ناني',
#    'انيت',
#    'نيته',
#    'يتها',
#    'وصلو',
#    'صلوه',
#    'لوها',
#    'يستن',
#    'ستنى',
#    'خاطر',
#    'اطره',
#    'طرها',
#    'ال',
#    'لص',
#    'صر',
#    'را',
#    'اح',
#    'حه',
#    'ان',
#    'نا',
#    'عا',
#    'ار',
#    'رف',
#    'فه',
#    'ات',
#    'تع',
#    'عا',
#    'اط',
#    'طف',
#    'مع',
#    'عا',
#    'اه',
#    'ها',
#    'دل',
#    'لع',
#    'عه',
#    'ها',
#    'ان',
#    'نا',
#    'ان',
#    'ني',
#    'يت',
#    'ته',
#    'ها',
#    'ال',
#    'لل',
#    'لى',
#    'وص',
#    'صل',
#    'لو',
#    'وه',
#    'ها',
#    'لك',
#    'كد',
#    'ده',
#    'شغ',
#    'غل',
#    'له',
#    'لا',
#    'از',
#    'زم',
#    'يس',
#    'ست',
#    'تن',
#    'نى',
#    'عش',
#    'شا',
#    'ان',
#    'خا',
#    'اط',
#    'طر',
#    'ره',
#    'ها'],
#   'neg'),
#  (['سبق',
#    'تم',
#    'الامر',
#    'الا',
#    'لام',
#    'امر',
#    'الام',
#    'لامر',
#    'سب',
#    'بق',
#    'ال',
#    'لا',
#    'ام',
#    'مر'],
#   'neu'),
#  (['ضحكتها',
#    'لوحدها',
#    'قصيــده',
#    'شعــر',
#    'ضحك',
#    'حكت',
#    'كته',
#    'تها',
#    'لوح',
#    'وحد',
#    'حده',
#    'دها',
#    'قصي',
#    'صيـ',
#    'يــ',
#    'ــد',
#    'ـده',
#    'شعـ',
#    'عــ',
#    'ــر',
#    'ضحكت',
#    'حكته',
#    'كتها',
#    'لوحد',
#    'وحده',
#    'حدها',
#    'قصيـ',
#    'صيــ',
#    'يــد',
#    'ــده',
#    'شعــ',
#    'عــر',
#    'ضح',
#    'حك',
#    'كت',
#    'ته',
#    'ها',
#    'لو',
#    'وح',
#    'حد',
#    'ده',
#    'ها',
#    'قص',
#    'صي',
#    'يـ',
#    'ــ',
#    'ـد',
#    'ده',
#    'شع',
#    'عـ',
#    'ــ',
#    'ـر'],
#   'pos'),
#  (['تصريح',
#    'السبسي',
#    'يطلب',
#    'تفويضا',
#    'الشعب',
#    'لمواجهة',
#    'إرهاب',
#    'محتمل',
#    'واضح',
#    'الكتلوج',
#    'تصر',
#    'صري',
#    'ريح',
#    'الس',
#    'لسب',
#    'سبس',
#    'بسي',
#    'يطل',
#    'طلب',
#    'تفو',
#    'فوي',
#    'ويض',
#    'يضا',
#    'الش',
#    'لشع',
#    'شعب',
#    'لمو',
#    'موا',
#    'واج',
#    'اجه',
#    'جهة',
#    'إره',
#    'رها',
#    'هاب',
#    'محت',
#    'حتم',
#    'تمل',
#    'واض',
#    'اضح',
#    'الك',
#    'لكت',
#    'كتل',
#    'تلو',
#    'لوج',
#    'تصري',
#    'صريح',
#    'السب',
#    'لسبس',
#    'سبسي',
#    'تفوي',
#    'فويض',
#    'ويضا',
#    'الشع',
#    'لشعب',
#    'لموا',
#    'مواج',
#    'واجه',
#    'اجهة',
#    'إرها',
#    'رهاب',
#    'محتم',
#    'حتمل',
#    'الكت',
#    'لكتل',
#    'كتلو',
#    'تلوج',
#    'تص',
#    'صر',
#    'ري',
#    'يح',
#    'ال',
#    'لس',
#    'سب',
#    'بس',
#    'سي',
#    'يط',
#    'طل',
#    'لب',
#    'تف',
#    'فو',
#    'وي',
#    'يض',
#    'ضا',
#    'ال',
#    'لش',
#    'شع',
#    'عب',
#    'لم',
#    'مو',
#    'وا',
#    'اج',
#    'جه',
#    'هة',
#    'إر',
#    'ره',
#    'ها',
#    'اب',
#    'مح',
#    'حت',
#    'تم',
#    'مل',
#    'وا',
#    'اض',
#    'ضح',
#    'ال',
#    'لك',
#    'كت',
#    'تل',
#    'لو',
#    'وج'],
#   'neg'),
#  (['يعني',
#    'ماريتيمو',
#    'عايزين',
#    'مليون',
#    'علشان',
#    'يرجعوا',
#    'محمد',
#    'ابراهيم',
#    'وانبي',
#    'عايزه',
#    'مليون',
#    'مومن',
#    'زكريا',
#    'يعن',
#    'عني',
#    'مار',
#    'اري',
#    'ريت',
#    'يتي',
#    'تيم',
#    'يمو',
#    'عاي',
#    'ايز',
#    'يزي',
#    'زين',
#    'ملي',
#    'ليو',
#    'يون',
#    'علش',
#    'لشا',
#    'شان',
#    'يرج',
#    'رجع',
#    'جعو',
#    'عوا',
#    'محم',
#    'حمد',
#    'ابر',
#    'برا',
#    'راه',
#    'اهي',
#    'هيم',
#    'وان',
#    'انب',
#    'نبي',
#    'عاي',
#    'ايز',
#    'يزه',
#    'ملي',
#    'ليو',
#    'يون',
#    'موم',
#    'ومن',
#    'زكر',
#    'كري',
#    'ريا',
#    'ماري',
#    'اريت',
#    'ريتي',
#    'يتيم',
#    'تيمو',
#    'عايز',
#    'ايزي',
#    'يزين',
#    'مليو',
#    'ليون',
#    'علشا',
#    'لشان',
#    'يرجع',
#    'رجعو',
#    'جعوا',
#    'ابرا',
#    'براه',
#    'راهي',
#    'اهيم',
#    'وانب',
#    'انبي',
#    'عايز',
#    'ايزه',
#    'مليو',
#    'ليون',
#    'زكري',
#    'كريا',
#    'يع',
#    'عن',
#    'ني',
#    'ما',
#    'ار',
#    'ري',
#    'يت',
#    'تي',
#    'يم',
#    'مو',
#    'عا',
#    'اي',
#    'يز',
#    'زي',
#    'ين',
#    'مل',
#    'لي',
#    'يو',
#    'ون',
#    'عل',
#    'لش',
#    'شا',
#    'ان',
#    'ير',
#    'رج',
#    'جع',
#    'عو',
#    'وا',
#    'مح',
#    'حم',
#    'مد',
#    'اب',
#    'بر',
#    'را',
#    'اه',
#    'هي',
#    'يم',
#    'وا',
#    'ان',
#    'نب',
#    'بي',
#    'عا',
#    'اي',
#    'يز',
#    'زه',
#    'مل',
#    'لي',
#    'يو',
#    'ون',
#    'مو',
#    'وم',
#    'من',
#    'زك',
#    'كر',
#    'ري',
#    'يا'],
#   'neg'),
#  (['صباحك',
#    'ويومك',
#    'جميل',
#    'انشاءلله',
#    'مرسي',
#    'لذوقك',
#    'صبا',
#    'باح',
#    'احك',
#    'ويو',
#    'يوم',
#    'ومك',
#    'جمي',
#    'ميل',
#    'انش',
#    'نشا',
#    'شاء',
#    'اءل',
#    'ءلل',
#    'لله',
#    'مرس',
#    'رسي',
#    'لذو',
#    'ذوق',
#    'وقك',
#    'صباح',
#    'باحك',
#    'ويوم',
#    'يومك',
#    'انشا',
#    'نشاء',
#    'شاءل',
#    'اءلل',
#    'ءلله',
#    'لذوق',
#    'ذوقك',
#    'صب',
#    'با',
#    'اح',
#    'حك',
#    'وي',
#    'يو',
#    'وم',
#    'مك',
#    'جم',
#    'مي',
#    'يل',
#    'ان',
#    'نش',
#    'شا',
#    'اء',
#    'ءل',
#    'لل',
#    'له',
#    'مر',
#    'رس',
#    'سي',
#    'لذ',
#    'ذو',
#    'وق',
#    'قك'],
#   'pos'),
#  (['انت',
#    'الموبيل',
#    'الكمبيوتر',
#    'الم',
#    'لمو',
#    'موب',
#    'وبي',
#    'بيل',
#    'الك',
#    'لكم',
#    'كمب',
#    'مبي',
#    'بيو',
#    'يوت',
#    'وتر',
#    'المو',
#    'لموب',
#    'موبي',
#    'وبيل',
#    'الكم',
#    'لكمب',
#    'كمبي',
#    'مبيو',
#    'بيوت',
#    'يوتر',
#    'ان',
#    'نت',
#    'ال',
#    'لم',
#    'مو',
#    'وب',
#    'بي',
#    'يل',
#    'ال',
#    'لك',
#    'كم',
#    'مب',
#    'بي',
#    'يو',
#    'وت',
#    'تر'],
#   'neu'),
#  (['حاجة',
#    'وسخه',
#    'هارميه',
#    'فعلا',
#    'لاني',
#    'زهقت',
#    'حاج',
#    'اجة',
#    'وسخ',
#    'سخه',
#    'هار',
#    'ارم',
#    'رمي',
#    'ميه',
#    'فعل',
#    'علا',
#    'لان',
#    'اني',
#    'زهق',
#    'هقت',
#    'هارم',
#    'ارمي',
#    'رميه',
#    'حا',
#    'اج',
#    'جة',
#    'وس',
#    'سخ',
#    'خه',
#    'ها',
#    'ار',
#    'رم',
#    'مي',
#    'يه',
#    'فع',
#    'عل',
#    'لا',
#    'لا',
#    'ان',
#    'ني',
#    'زه',
#    'هق',
#    'قت'],
#   'neg'),
#  (['امين',
#    'الصوره',
#    'واضح',
#    'فبركة',
#    'تنبيه',
#    'امي',
#    'مين',
#    'الص',
#    'لصو',
#    'صور',
#    'وره',
#    'واض',
#    'اضح',
#    'فبر',
#    'برك',
#    'ركة',
#    'تنب',
#    'نبي',
#    'بيه',
#    'الصو',
#    'لصور',
#    'صوره',
#    'فبرك',
#    'بركة',
#    'تنبي',
#    'نبيه',
#    'ام',
#    'مي',
#    'ين',
#    'ال',
#    'لص',
#    'صو',
#    'ور',
#    'ره',
#    'وا',
#    'اض',
#    'ضح',
#    'فب',
#    'بر',
#    'رك',
#    'كة',
#    'تن',
#    'نب',
#    'بي',
#    'يه'],
#   'neg'),
#  (['انا',
#    'مش',
#    'هعيش',
#    'طول',
#    'عمري',
#    'ملاك',
#    'هعي',
#    'عيش',
#    'عمر',
#    'مري',
#    'ملا',
#    'لاك',
#    'ان',
#    'نا',
#    'هع',
#    'عي',
#    'يش',
#    'طو',
#    'ول',
#    'عم',
#    'مر',
#    'ري',
#    'مل',
#    'لا',
#    'اك'],
#   'neg'),
#  (['بارك',
#    'الله',
#    'فيك',
#    'وجزاك',
#    'خيرا',
#    'بار',
#    'ارك',
#    'الل',
#    'لله',
#    'وجز',
#    'جزا',
#    'زاك',
#    'خير',
#    'يرا',
#    'وجزا',
#    'جزاك',
#    'با',
#    'ار',
#    'رك',
#    'ال',
#    'لل',
#    'له',
#    'في',
#    'يك',
#    'وج',
#    'جز',
#    'زا',
#    'اك',
#    'خي',
#    'ير',
#    'را'],
#   'pos'),
#  (['اني',
#    'نفسي',
#    'تبقي',
#    'مدير',
#    'فني',
#    'فعلا',
#    'انته',
#    'بتحب',
#    'النادي',
#    'وبتخاف',
#    'وبتدعمه',
#    'اي',
#    'مكان',
#    'وانا',
#    'عارف',
#    'انك',
#    'بتعد',
#    'نفسك',
#    'اكتر',
#    'واحسن',
#    'الاول',
#    'نفس',
#    'فسي',
#    'تبق',
#    'بقي',
#    'مدي',
#    'دير',
#    'فعل',
#    'علا',
#    'انت',
#    'نته',
#    'بتح',
#    'تحب',
#    'الن',
#    'لنا',
#    'ناد',
#    'ادي',
#    'وبت',
#    'بتخ',
#    'تخا',
#    'خاف',
#    'وبت',
#    'بتد',
#    'تدع',
#    'دعم',
#    'عمه',
#    'مكا',
#    'كان',
#    'وان',
#    'انا',
#    'عار',
#    'ارف',
#    'بتع',
#    'تعد',
#    'نفس',
#    'فسك',
#    'اكت',
#    'كتر',
#    'واح',
#    'احس',
#    'حسن',
#    'الا',
#    'لاو',
#    'اول',
#    'النا',
#    'لناد',
#    'نادي',
#    'وبتخ',
#    'بتخا',
#    'تخاف',
#    'وبتد',
#    'بتدع',
#    'تدعم',
#    'دعمه',
#    'واحس',
#    'احسن',
#    'الاو',
#    'لاول',
#    'ان',
#    'ني',
#    'نف',
#    'فس',
#    'سي',
#    'تب',
#    'بق',
#    'قي',
#    'مد',
#    'دي',
#    'ير',
#    'فن',
#    'ني',
#    'فع',
#    'عل',
#    'لا',
#    'ان',
#    'نت',
#    'ته',
#    'بت',
#    'تح',
#    'حب',
#    'ال',
#    'لن',
#    'نا',
#    'اد',
#    'دي',
#    'وب',
#    'بت',
#    'تخ',
#    'خا',
#    'اف',
#    'وب',
#    'بت',
#    'تد',
#    'دع',
#    'عم',
#    'مه',
#    'مك',
#    'كا',
#    'ان',
#    'وا',
#    'ان',
#    'نا',
#    'عا',
#    'ار',
#    'رف',
#    'ان',
#    'نك',
#    'بت',
#    'تع',
#    'عد',
#    'نف',
#    'فس',
#    'سك',
#    'اك',
#    'كت',
#    'تر',
#    'وا',
#    'اح',
#    'حس',
#    'سن',
#    'ال',
#    'لا',
#    'او',
#    'ول'],
#   'pos'),
#  (['تعتبر',
#    'حد',
#    'عايش',
#    'انه',
#    'مات',
#    'دى',
#    'بتبقى',
#    'اصعي',
#    'موته',
#    'تعت',
#    'عتب',
#    'تبر',
#    'عاي',
#    'ايش',
#    'بتب',
#    'تبق',
#    'بقى',
#    'اصع',
#    'صعي',
#    'موت',
#    'وته',
#    'تعتب',
#    'عتبر',
#    'بتبق',
#    'تبقى',
#    'تع',
#    'عت',
#    'تب',
#    'بر',
#    'عا',
#    'اي',
#    'يش',
#    'ان',
#    'نه',
#    'ما',
#    'ات',
#    'بت',
#    'تب',
#    'بق',
#    'قى',
#    'اص',
#    'صع',
#    'عي',
#    'مو',
#    'وت',
#    'ته'],
#   'neg'),
#  (['ممكن',
#    'اتغير',
#    'علي',
#    'انسان',
#    'بنسبة',
#    'لمجرد',
#    'انه',
#    'ابن',
#    'وسخة',
#    'بينسي',
#    'الجميل',
#    'والجدعنة',
#    'اللي',
#    'كانت',
#    'بتتعمل',
#    'معاه',
#    'موجه',
#    'ممك',
#    'مكن',
#    'اتغ',
#    'تغي',
#    'غير',
#    'انس',
#    'نسا',
#    'سان',
#    'بنس',
#    'نسب',
#    'سبة',
#    'لمج',
#    'مجر',
#    'جرد',
#    'وسخ',
#    'سخة',
#    'بين',
#    'ينس',
#    'نسي',
#    'الج',
#    'لجم',
#    'جمي',
#    'ميل',
#    'وال',
#    'الج',
#    'لجد',
#    'جدع',
#    'دعن',
#    'عنة',
#    'الل',
#    'للي',
#    'كان',
#    'انت',
#    'بتت',
#    'تتع',
#    'تعم',
#    'عمل',
#    'معا',
#    'عاه',
#    'موج',
#    'وجه',
#    'اتغي',
#    'تغير',
#    'انسا',
#    'نسان',
#    'بنسب',
#    'نسبة',
#    'لمجر',
#    'مجرد',
#    'بينس',
#    'ينسي',
#    'الجم',
#    'لجمي',
#    'جميل',
#    'والج',
#    'الجد',
#    'لجدع',
#    'جدعن',
#    'دعنة',
#    'بتتع',
#    'تتعم',
#    'تعمل',
#    'مم',
#    'مك',
#    'كن',
#    'ات',
#    'تغ',
#    'غي',
#    'ير',
#    'عل',
#    'لي',
#    'ان',
#    'نس',
#    'سا',
#    'ان',
#    'بن',
#    'نس',
#    'سب',
#    'بة',
#    'لم',
#    'مج',
#    'جر',
#    'رد',
#    'ان',
#    'نه',
#    'اب',
#    'بن',
#    'وس',
#    'سخ',
#    'خة',
#    'بي',
#    'ين',
#    'نس',
#    'سي',
#    'ال',
#    'لج',
#    'جم',
#    'مي',
#    'يل',
#    'وا',
#    'ال',
#    'لج',
#    'جد',
#    'دع',
#    'عن',
#    'نة',
#    'ال',
#    'لل',
#    'لي',
#    'كا',
#    'ان',
#    'نت',
#    'بت',
#    'تت',
#    'تع',
#    'عم',
#    'مل',
#    'مع',
#    'عا',
#    'اه',
#    'مو',
#    'وج',
#    'جه'],
#   'neg'),
#  (['الراحه',
#    'النفسيه',
#    'لاحد',
#    'معين',
#    'الر',
#    'لرا',
#    'راح',
#    'احه',
#    'الن',
#    'لنف',
#    'نفس',
#    'فسي',
#    'سيه',
#    'لاح',
#    'احد',
#    'معي',
#    'عين',
#    'الرا',
#    'لراح',
#    'راحه',
#    'النف',
#    'لنفس',
#    'نفسي',
#    'فسيه',
#    'ال',
#    'لر',
#    'را',
#    'اح',
#    'حه',
#    'ال',
#    'لن',
#    'نف',
#    'فس',
#    'سي',
#    'يه',
#    'لا',
#    'اح',
#    'حد',
#    'مع',
#    'عي',
#    'ين'],
#   'pos'),
#  (['هه', 'ماشي', 'خقه', 'ماش', 'اشي', 'ما', 'اش', 'شي', 'خق', 'قه'], 'pos'),
#  (['ربنا',
#    'يخليكم',
#    'لبعض',
#    'ربن',
#    'بنا',
#    'يخل',
#    'خلي',
#    'ليك',
#    'يكم',
#    'لبع',
#    'بعض',
#    'يخلي',
#    'خليك',
#    'ليكم',
#    'رب',
#    'بن',
#    'نا',
#    'يخ',
#    'خل',
#    'لي',
#    'يك',
#    'كم',
#    'لب',
#    'بع',
#    'عض'],
#   'pos'),
#  (['أحا',
#    'أحوه',
#    'كس',
#    'حسام',
#    'وأخوه',
#    'أحو',
#    'حوه',
#    'حسا',
#    'سام',
#    'وأخ',
#    'أخو',
#    'خوه',
#    'وأخو',
#    'أخوه',
#    'أح',
#    'حا',
#    'أح',
#    'حو',
#    'وه',
#    'حس',
#    'سا',
#    'ام',
#    'وأ',
#    'أخ',
#    'خو',
#    'وه'],
#   'neg'),
#  (['اى',
#    'مسلسلات',
#    'لاى',
#    'جنسية',
#    'بيبقوا',
#    'مهتمين',
#    'بابراز',
#    'اجمل',
#    'فى',
#    'بلادهم',
#    'احنا',
#    'اعوذ',
#    'بالله',
#    'بنتففن',
#    'فى',
#    'اظهار',
#    'القبيح',
#    'مسل',
#    'سلس',
#    'لسل',
#    'سلا',
#    'لات',
#    'جنس',
#    'نسي',
#    'سية',
#    'بيب',
#    'يبق',
#    'بقو',
#    'قوا',
#    'مهت',
#    'هتم',
#    'تمي',
#    'مين',
#    'باب',
#    'ابر',
#    'برا',
#    'راز',
#    'اجم',
#    'جمل',
#    'بلا',
#    'لاد',
#    'اده',
#    'دهم',
#    'احن',
#    'حنا',
#    'اعو',
#    'عوذ',
#    'بال',
#    'الل',
#    'لله',
#    'بنت',
#    'نتف',
#    'تفف',
#    'ففن',
#    'اظه',
#    'ظها',
#    'هار',
#    'الق',
#    'لقب',
#    'قبي',
#    'بيح',
#    'مسلس',
#    'سلسل',
#    'لسلا',
#    'سلات',
#    'جنسي',
#    'نسية',
#    'بيبق',
#    'يبقو',
#    'بقوا',
#    'مهتم',
#    'هتمي',
#    'تمين',
#    'بابر',
#    'ابرا',
#    'براز',
#    'بلاد',
#    'لاده',
#    'ادهم',
#    'بالل',
#    'الله',
#    'بنتف',
#    'نتفف',
#    'تففن',
#    'اظها',
#    'ظهار',
#    'القب',
#    'لقبي',
#    'قبيح',
#    'مس',
#    'سل',
#    'لس',
#    'سل',
#    'لا',
#    'ات',
#    'لا',
#    'اى',
#    'جن',
#    'نس',
#    'سي',
#    'ية',
#    'بي',
#    'يب',
#    'بق',
#    'قو',
#    'وا',
#    'مه',
#    'هت',
#    'تم',
#    'مي',
#    'ين',
#    'با',
#    'اب',
#    'بر',
#    'را',
#    'از',
#    'اج',
#    'جم',
#    'مل',
#    'بل',
#    'لا',
#    'اد',
#    'ده',
#    'هم',
#    'اح',
#    'حن',
#    'نا',
#    'اع',
#    'عو',
#    'وذ',
#    'با',
#    'ال',
#    'لل',
#    'له',
#    'بن',
#    'نت',
#    'تف',
#    'فف',
#    'فن',
#    'اظ',
#    'ظه',
#    'ها',
#    'ار',
#    'ال',
#    'لق',
#    'قب',
#    'بي',
#    'يح'],
#   'neg'),
#  (['شيروو',
#    'كاان',
#    'نفسناا',
#    'تحضري',
#    'ووتولعوها',
#    'المصريين',
#    'تتعوض',
#    'ياريت',
#    'تحتفلو',
#    'بعيد',
#    'ميلادو',
#    'شير',
#    'يرو',
#    'روو',
#    'كاا',
#    'اان',
#    'نفس',
#    'فسن',
#    'سنا',
#    'ناا',
#    'تحض',
#    'حضر',
#    'ضري',
#    'ووت',
#    'وتو',
#    'تول',
#    'ولع',
#    'لعو',
#    'عوه',
#    'وها',
#    'الم',
#    'لمص',
#    'مصر',
#    'صري',
#    'ريي',
#    'يين',
#    'تتع',
#    'تعو',
#    'عوض',
#    'يار',
#    'اري',
#    'ريت',
#    'تحت',
#    'حتف',
#    'تفل',
#    'فلو',
#    'بعي',
#    'عيد',
#    'ميل',
#    'يلا',
#    'لاد',
#    'ادو',
#    'شيرو',
#    'يروو',
#    'نفسن',
#    'فسنا',
#    'سناا',
#    'تحضر',
#    'حضري',
#    'ووتو',
#    'وتول',
#    'تولع',
#    'ولعو',
#    'لعوه',
#    'عوها',
#    'المص',
#    'لمصر',
#    'مصري',
#    'صريي',
#    'ريين',
#    'تتعو',
#    'تعوض',
#    'ياري',
#    'اريت',
#    'تحتف',
#    'حتفل',
#    'تفلو',
#    'ميلا',
#    'يلاد',
#    'لادو',
#    'شي',
#    'ير',
#    'رو',
#    'وو',
#    'كا',
#    'اا',
#    'ان',
#    'نف',
#    'فس',
#    'سن',
#    'نا',
#    'اا',
#    'تح',
#    'حض',
#    'ضر',
#    'ري',
#    'وو',
#    'وت',
#    'تو',
#    'ول',
#    'لع',
#    'عو',
#    'وه',
#    'ها',
#    'ال',
#    'لم',
#    'مص',
#    'صر',
#    'ري',
#    'يي',
#    'ين',
#    'تت',
#    'تع',
#    'عو',
#    'وض',
#    'يا',
#    'ار',
#    'ري',
#    'يت',
#    'تح',
#    'حت',
#    'تف',
#    'فل',
#    'لو',
#    'بع',
#    'عي',
#    'يد',
#    'مي',
#    'يل',
#    'لا',
#    'اد',
#    'دو'],
#   'pos'),
#  (['لثبات',
#    'قلبك',
#    'لثب',
#    'ثبا',
#    'بات',
#    'قلب',
#    'لبك',
#    'لثبا',
#    'ثبات',
#    'لث',
#    'ثب',
#    'با',
#    'ات',
#    'قل',
#    'لب',
#    'بك'],
#   'pos'),
#  (['وأرجع',
#    'تانى',
#    'وأقولك',
#    'الله',
#    'يخليك',
#    'وأر',
#    'أرج',
#    'رجع',
#    'تان',
#    'انى',
#    'وأق',
#    'أقو',
#    'قول',
#    'ولك',
#    'الل',
#    'لله',
#    'يخل',
#    'خلي',
#    'ليك',
#    'وأرج',
#    'أرجع',
#    'وأقو',
#    'أقول',
#    'قولك',
#    'يخلي',
#    'خليك',
#    'وأ',
#    'أر',
#    'رج',
#    'جع',
#    'تا',
#    'ان',
#    'نى',
#    'وأ',
#    'أق',
#    'قو',
#    'ول',
#    'لك',
#    'ال',
#    'لل',
#    'له',
#    'يخ',
#    'خل',
#    'لي',
#    'يك'],
#   'pos'),
#  (['مادة',
#    'بتنفهم',
#    'بندرس',
#    'لليش',
#    'ماد',
#    'ادة',
#    'بتن',
#    'تنف',
#    'نفه',
#    'فهم',
#    'بند',
#    'ندر',
#    'درس',
#    'للي',
#    'ليش',
#    'بتنف',
#    'تنفه',
#    'نفهم',
#    'بندر',
#    'ندرس',
#    'ما',
#    'اد',
#    'دة',
#    'بت',
#    'تن',
#    'نف',
#    'فه',
#    'هم',
#    'بن',
#    'ند',
#    'در',
#    'رس',
#    'لل',
#    'لي',
#    'يش'],
#   'neg'),
#  (['تتوقعي',
#    'انتي',
#    'هتشوفي',
#    'خيرف',
#    'حياتك',
#    'تتو',
#    'توق',
#    'وقع',
#    'قعي',
#    'انت',
#    'نتي',
#    'هتش',
#    'تشو',
#    'شوف',
#    'وفي',
#    'خير',
#    'يرف',
#    'حيا',
#    'يات',
#    'اتك',
#    'تتوق',
#    'توقع',
#    'وقعي',
#    'هتشو',
#    'تشوف',
#    'شوفي',
#    'حيات',
#    'ياتك',
#    'تت',
#    'تو',
#    'وق',
#    'قع',
#    'عي',
#    'ان',
#    'نت',
#    'تي',
#    'هت',
#    'تش',
#    'شو',
#    'وف',
#    'في',
#    'خي',
#    'ير',
#    'رف',
#    'حي',
#    'يا',
#    'ات',
#    'تك'],
#   'neg'),
#  (['يحب',
#    'يجرؤ',
#    'مرور',
#    'الوقت',
#    'بدونك',
#    'يحن',
#    'يشتاق',
#    'يتألم',
#    'يص',
#    'نع',
#    'المستحيل',
#    'ليحادثك',
#    'يجر',
#    'جرؤ',
#    'مرو',
#    'رور',
#    'الو',
#    'لوق',
#    'وقت',
#    'بدو',
#    'دون',
#    'ونك',
#    'يشت',
#    'شتا',
#    'تاق',
#    'يتأ',
#    'تأل',
#    'ألم',
#    'الم',
#    'لمس',
#    'مست',
#    'ستح',
#    'تحي',
#    'حيل',
#    'ليح',
#    'يحا',
#    'حاد',
#    'ادث',
#    'دثك',
#    'الوق',
#    'لوقت',
#    'بدون',
#    'دونك',
#    'يشتا',
#    'شتاق',
#    'يتأل',
#    'تألم',
#    'المس',
#    'لمست',
#    'مستح',
#    'ستحي',
#    'تحيل',
#    'ليحا',
#    'يحاد',
#    'حادث',
#    'ادثك',
#    'يح',
#    'حب',
#    'يج',
#    'جر',
#    'رؤ',
#    'مر',
#    'رو',
#    'ور',
#    'ال',
#    'لو',
#    'وق',
#    'قت',
#    'بد',
#    'دو',
#    'ون',
#    'نك',
#    'يح',
#    'حن',
#    'يش',
#    'شت',
#    'تا',
#    'اق',
#    'يت',
#    'تأ',
#    'أل',
#    'لم',
#    'ال',
#    'لم',
#    'مس',
#    'ست',
#    'تح',
#    'حي',
#    'يل',
#    'لي',
#    'يح',
#    'حا',
#    'اد',
#    'دث',
#    'ثك'],
#   'pos'),
#  (['بيبقي',
#    'مستني',
#    'الكلمة',
#    'التاني',
#    'فمحدش',
#    'بيقولها',
#    'فبتفرقهم',
#    'الايام',
#    'بيب',
#    'يبق',
#    'بقي',
#    'مست',
#    'ستن',
#    'تني',
#    'الك',
#    'لكل',
#    'كلم',
#    'لمة',
#    'الت',
#    'لتا',
#    'تان',
#    'اني',
#    'فمح',
#    'محد',
#    'حدش',
#    'بيق',
#    'يقو',
#    'قول',
#    'وله',
#    'لها',
#    'فبت',
#    'بتف',
#    'تفر',
#    'فرق',
#    'رقه',
#    'قهم',
#    'الا',
#    'لاي',
#    'ايا',
#    'يام',
#    'بيبق',
#    'يبقي',
#    'مستن',
#    'ستني',
#    'الكل',
#    'لكلم',
#    'كلمة',
#    'التا',
#    'لتان',
#    'تاني',
#    'فمحد',
#    'محدش',
#    'بيقو',
#    'يقول',
#    'قوله',
#    'ولها',
#    'فبتف',
#    'بتفر',
#    'تفرق',
#    'فرقه',
#    'رقهم',
#    'الاي',
#    'لايا',
#    'ايام',
#    'بي',
#    'يب',
#    'بق',
#    'قي',
#    'مس',
#    'ست',
#    'تن',
#    'ني',
#    'ال',
#    'لك',
#    'كل',
#    'لم',
#    'مة',
#    'ال',
#    'لت',
#    'تا',
#    'ان',
#    'ني',
#    'فم',
#    'مح',
#    'حد',
#    'دش',
#    'بي',
#    'يق',
#    'قو',
#    'ول',
#    'له',
#    'ها',
#    'فب',
#    'بت',
#    'تف',
#    'فر',
#    'رق',
#    'قه',
#    'هم',
#    'ال',
#    'لا',
#    'اي',
#    'يا',
#    'ام'],
#   'neg'),
#  (['طبعا',
#    'انتي',
#    'سقعانين',
#    'وانا',
#    'كمان',
#    'انا',
#    'عرقان',
#    'والسخونيه',
#    'ديه',
#    'بنت',
#    'جزمه',
#    'طبع',
#    'بعا',
#    'انت',
#    'نتي',
#    'سقع',
#    'قعا',
#    'عان',
#    'اني',
#    'نين',
#    'وان',
#    'انا',
#    'كما',
#    'مان',
#    'عرق',
#    'رقا',
#    'قان',
#    'وال',
#    'الس',
#    'لسخ',
#    'سخو',
#    'خون',
#    'وني',
#    'نيه',
#    'جزم',
#    'زمه',
#    'سقعا',
#    'قعان',
#    'عاني',
#    'انين',
#    'عرقا',
#    'رقان',
#    'والس',
#    'السخ',
#    'لسخو',
#    'سخون',
#    'خوني',
#    'ونيه',
#    'طب',
#    'بع',
#    'عا',
#    'ان',
#    'نت',
#    'تي',
#    'سق',
#    'قع',
#    'عا',
#    'ان',
#    'ني',
#    'ين',
#    'وا',
#    'ان',
#    'نا',
#    'كم',
#    'ما',
#    'ان',
#    'ان',
#    'نا',
#    'عر',
#    'رق',
#    'قا',
#    'ان',
#    'وا',
#    'ال',
#    'لس',
#    'سخ',
#    'خو',
#    'ون',
#    'ني',
#    'يه',
#    'دي',
#    'يه',
#    'بن',
#    'نت',
#    'جز',
#    'زم',
#    'مه'],
#   'neg'),
#  (['انا',
#    'عايز',
#    'احكى',
#    'قصة',
#    'محتاج',
#    'حد',
#    'يكتبها',
#    'معايا',
#    'حد',
#    'راشق',
#    'عاي',
#    'ايز',
#    'احك',
#    'حكى',
#    'محت',
#    'حتا',
#    'تاج',
#    'يكت',
#    'كتب',
#    'تبه',
#    'بها',
#    'معا',
#    'عاي',
#    'ايا',
#    'راش',
#    'اشق',
#    'محتا',
#    'حتاج',
#    'يكتب',
#    'كتبه',
#    'تبها',
#    'معاي',
#    'عايا',
#    'ان',
#    'نا',
#    'عا',
#    'اي',
#    'يز',
#    'اح',
#    'حك',
#    'كى',
#    'قص',
#    'صة',
#    'مح',
#    'حت',
#    'تا',
#    'اج',
#    'يك',
#    'كت',
#    'تب',
#    'به',
#    'ها',
#    'مع',
#    'عا',
#    'اي',
#    'يا',
#    'را',
#    'اش',
#    'شق'],
#   'neu'),
#  (['يآب',
#    'ـو',
#    'الش',
#    'يء',
#    'الو',
#    'حيد',
#    'الذ',
#    'أست',
#    'جآوز',
#    'جآو',
#    'آوز',
#    'يآ',
#    'آب',
#    'ال',
#    'لش',
#    'ال',
#    'لو',
#    'حي',
#    'يد',
#    'ال',
#    'لذ',
#    'أس',
#    'ست',
#    'جآ',
#    'آو',
#    'وز'],
#   'neu'),
#  (['الاسبوع',
#    'هادا',
#    'افكر',
#    'بدو',
#    'يمرق',
#    'برج',
#    'راسي',
#    'انو',
#    'احاول',
#    'انسى',
#    'وبرجع',
#    'بفكر',
#    'مش',
#    'هييك',
#    'الا',
#    'لاس',
#    'اسب',
#    'سبو',
#    'بوع',
#    'هاد',
#    'ادا',
#    'افك',
#    'فكر',
#    'يمر',
#    'مرق',
#    'راس',
#    'اسي',
#    'احا',
#    'حاو',
#    'اول',
#    'انس',
#    'نسى',
#    'وبر',
#    'برج',
#    'رجع',
#    'بفك',
#    'فكر',
#    'هيي',
#    'ييك',
#    'الاس',
#    'لاسب',
#    'اسبو',
#    'سبوع',
#    'احاو',
#    'حاول',
#    'وبرج',
#    'برجع',
#    'ال',
#    'لا',
#    'اس',
#    'سب',
#    'بو',
#    'وع',
#    'ها',
#    'اد',
#    'دا',
#    'اف',
#    'فك',
#    'كر',
#    'بد',
#    'دو',
#    'يم',
#    'مر',
#    'رق',
#    'بر',
#    'رج',
#    'را',
#    'اس',
#    'سي',
#    'ان',
#    'نو',
#    'اح',
#    'حا',
#    'او',
#    'ول',
#    'ان',
#    'نس',
#    'سى',
#    'وب',
#    'بر',
#    'رج',
#    'جع',
#    'بف',
#    'فك',
#    'كر',
#    'هي',
#    'يي',
#    'يك'],
#   'neg'),
#  (['ابقي',
#    'اعرف',
#    'قيمتك',
#    'عندهم',
#    'الاول',
#    'تقولهم',
#    'عشان',
#    'خاطري',
#    'ابق',
#    'بقي',
#    'اعر',
#    'عرف',
#    'قيم',
#    'يمت',
#    'متك',
#    'عند',
#    'نده',
#    'دهم',
#    'الا',
#    'لاو',
#    'اول',
#    'تقو',
#    'قول',
#    'وله',
#    'لهم',
#    'عشا',
#    'شان',
#    'خاط',
#    'اطر',
#    'طري',
#    'قيمت',
#    'يمتك',
#    'عنده',
#    'ندهم',
#    'الاو',
#    'لاول',
#    'تقول',
#    'قوله',
#    'ولهم',
#    'خاطر',
#    'اطري',
#    'اب',
#    'بق',
#    'قي',
#    'اع',
#    'عر',
#    'رف',
#    'قي',
#    'يم',
#    'مت',
#    'تك',
#    'عن',
#    'ند',
#    'ده',
#    'هم',
#    'ال',
#    'لا',
#    'او',
#    'ول',
#    'تق',
#    'قو',
#    'ول',
#    'له',
#    'هم',
#    'عش',
#    'شا',
#    'ان',
#    'خا',
#    'اط',
#    'طر',
#    'ري'],
#   'neg'),
#  (['شوفت',
#    'فتي',
#    'احلامي',
#    'لاتينو',
#    'داون',
#    'تاون',
#    'شوف',
#    'وفت',
#    'احل',
#    'حلا',
#    'لام',
#    'امي',
#    'لات',
#    'اتي',
#    'تين',
#    'ينو',
#    'داو',
#    'اون',
#    'تاو',
#    'اون',
#    'احلا',
#    'حلام',
#    'لامي',
#    'لاتي',
#    'اتين',
#    'تينو',
#    'شو',
#    'وف',
#    'فت',
#    'فت',
#    'تي',
#    'اح',
#    'حل',
#    'لا',
#    'ام',
#    'مي',
#    'لا',
#    'ات',
#    'تي',
#    'ين',
#    'نو',
#    'دا',
#    'او',
#    'ون',
#    'تا',
#    'او',
#    'ون'],
#   'pos'),
#  (['طيب',
#    'انا',
#    'بتكلم',
#    'المغرب',
#    'يرد',
#    'عليا',
#    'خرفان',
#    'نعاج',
#    'لييه',
#    'هرر',
#    'بتك',
#    'تكل',
#    'كلم',
#    'الم',
#    'لمغ',
#    'مغر',
#    'غرب',
#    'علي',
#    'ليا',
#    'خرف',
#    'رفا',
#    'فان',
#    'نعا',
#    'عاج',
#    'ليي',
#    'ييه',
#    'بتكل',
#    'تكلم',
#    'المغ',
#    'لمغر',
#    'مغرب',
#    'خرفا',
#    'رفان',
#    'طي',
#    'يب',
#    'ان',
#    'نا',
#    'بت',
#    'تك',
#    'كل',
#    'لم',
#    'ال',
#    'لم',
#    'مغ',
#    'غر',
#    'رب',
#    'ير',
#    'رد',
#    'عل',
#    'لي',
#    'يا',
#    'خر',
#    'رف',
#    'فا',
#    'ان',
#    'نع',
#    'عا',
#    'اج',
#    'لي',
#    'يي',
#    'يه',
#    'هر',
#    'رر'],
#   'neg'),
#  (['تيارات',
#    'الاسلام',
#    'السياسى',
#    'تقاتل',
#    'اى',
#    'استعمار',
#    'اوربى',
#    'للعالم',
#    'الاسلامى',
#    'اسرائيل',
#    'حاليا',
#    'تقاتل',
#    'الا',
#    'بنى',
#    'دينها',
#    'وبنى',
#    'عروبتها',
#    'تيا',
#    'يار',
#    'ارا',
#    'رات',
#    'الا',
#    'لاس',
#    'اسل',
#    'سلا',
#    'لام',
#    'الس',
#    'لسي',
#    'سيا',
#    'ياس',
#    'اسى',
#    'تقا',
#    'قات',
#    'اتل',
#    'است',
#    'ستع',
#    'تعم',
#    'عما',
#    'مار',
#    'اور',
#    'ورب',
#    'ربى',
#    'للع',
#    'لعا',
#    'عال',
#    'الم',
#    'الا',
#    'لاس',
#    'اسل',
#    'سلا',
#    'لام',
#    'امى',
#    'اسر',
#    'سرا',
#    'رائ',
#    'ائي',
#    'ئيل',
#    'حال',
#    'الي',
#    'ليا',
#    'تقا',
#    'قات',
#    'اتل',
#    'دين',
#    'ينه',
#    'نها',
#    'وبن',
#    'بنى',
#    'عرو',
#    'روب',
#    'وبت',
#    'بته',
#    'تها',
#    'تيار',
#    'يارا',
#    'ارات',
#    'الاس',
#    'لاسل',
#    'اسلا',
#    'سلام',
#    'السي',
#    'لسيا',
#    'سياس',
#    'ياسى',
#    'تقات',
#    'قاتل',
#    'استع',
#    'ستعم',
#    'تعما',
#    'عمار',
#    'اورب',
#    'وربى',
#    'للعا',
#    'لعال',
#    'عالم',
#    'الاس',
#    'لاسل',
#    'اسلا',
#    'سلام',
#    'لامى',
#    'اسرا',
#    'سرائ',
#    'رائي',
#    'ائيل',
#    'حالي',
#    'اليا',
#    'تقات',
#    'قاتل',
#    'دينه',
#    'ينها',
#    'عروب',
#    'روبت',
#    'وبته',
#    'بتها',
#    'تي',
#    'يا',
#    'ار',
#    'را',
#    'ات',
#    'ال',
#    'لا',
#    'اس',
#    'سل',
#    'لا',
#    'ام',
#    'ال',
#    'لس',
#    'سي',
#    'يا',
#    'اس',
#    'سى',
#    'تق',
#    'قا',
#    'ات',
#    'تل',
#    'اس',
#    'ست',
#    'تع',
#    'عم',
#    'ما',
#    'ار',
#    'او',
#    'ور',
#    'رب',
#    'بى',
#    'لل',
#    'لع',
#    'عا',
#    'ال',
#    'لم',
#    'ال',
#    'لا',
#    'اس',
#    'سل',
#    'لا',
#    'ام',
#    'مى',
#    'اس',
#    'سر',
#    'را',
#    'ائ',
#    'ئي',
#    'يل',
#    'حا',
#    'ال',
#    'لي',
#    'يا',
#    'تق',
#    'قا',
#    'ات',
#    'تل',
#    'ال',
#    'لا',
#    'بن',
#    'نى',
#    'دي',
#    'ين',
#    'نه',
#    'ها',
#    'وب',
#    'بن',
#    'نى',
#    'عر',
#    'رو',
#    'وب',
#    'بت',
#    'ته',
#    'ها'],
#   'neu'),
#  (['الكلاكس',
#    'آلة',
#    'تنبيه',
#    'فى',
#    'مصر',
#    'آلة',
#    'ازعاج',
#    'ياريت',
#    'ينزع',
#    'السيارات',
#    'لمدة',
#    'أشهر',
#    'لان',
#    'عدم',
#    'وجوده',
#    'بالسيارة',
#    'يجبر',
#    'قائدها',
#    'السير',
#    'بادب',
#    'الك',
#    'لكل',
#    'كلا',
#    'لاك',
#    'اكس',
#    'تنب',
#    'نبي',
#    'بيه',
#    'ازع',
#    'زعا',
#    'عاج',
#    'يار',
#    'اري',
#    'ريت',
#    'ينز',
#    'نزع',
#    'الس',
#    'لسي',
#    'سيا',
#    'يار',
#    'ارا',
#    'رات',
#    'لمد',
#    'مدة',
#    'أشه',
#    'شهر',
#    'وجو',
#    'جود',
#    'وده',
#    'بال',
#    'الس',
#    'لسي',
#    'سيا',
#    'يار',
#    'ارة',
#    'يجب',
#    'جبر',
#    'قائ',
#    'ائد',
#    'ئده',
#    'دها',
#    'الس',
#    'لسي',
#    'سير',
#    'باد',
#    'ادب',
#    'الكل',
#    'لكلا',
#    'كلاك',
#    'لاكس',
#    'تنبي',
#    'نبيه',
#    'ازعا',
#    'زعاج',
#    'ياري',
#    'اريت',
#    'السي',
#    'لسيا',
#    'سيار',
#    'يارا',
#    'ارات',
#    'وجود',
#    'جوده',
#    'بالس',
#    'السي',
#    'لسيا',
#    'سيار',
#    'يارة',
#    'قائد',
#    'ائده',
#    'ئدها',
#    'السي',
#    'لسير',
#    'ال',
#    'لك',
#    'كل',
#    'لا',
#    'اك',
#    'كس',
#    'آل',
#    'لة',
#    'تن',
#    'نب',
#    'بي',
#    'يه',
#    'مص',
#    'صر',
#    'آل',
#    'لة',
#    'از',
#    'زع',
#    'عا',
#    'اج',
#    'يا',
#    'ار',
#    'ري',
#    'يت',
#    'ين',
#    'نز',
#    'زع',
#    'ال',
#    'لس',
#    'سي',
#    'يا',
#    'ار',
#    'را',
#    'ات',
#    'لم',
#    'مد',
#    'دة',
#    'أش',
#    'شه',
#    'هر',
#    'لا',
#    'ان',
#    'عد',
#    'دم',
#    'وج',
#    'جو',
#    'ود',
#    'ده',
#    'با',
#    'ال',
#    'لس',
#    'سي',
#    'يا',
#    'ار',
#    'رة',
#    'يج',
#    'جب',
#    'بر',
#    'قا',
#    'ائ',
#    'ئد',
#    'ده',
#    'ها',
#    'ال',
#    'لس',
#    'سي',
#    'ير',
#    'با',
#    'اد',
#    'دب'],
#   'neg'),
#  (['الزمالكاويه',
#    'اللي',
#    'بيزيطوا',
#    'ان',
#    'الاهلي',
#    'اتغلب',
#    'اتلموا',
#    'بدل',
#    'نردح',
#    'وشكلكوا',
#    'يبقي',
#    'وحش',
#    'اكتر',
#    'هوا',
#    'الز',
#    'لزم',
#    'زما',
#    'مال',
#    'الك',
#    'لكا',
#    'كاو',
#    'اوي',
#    'ويه',
#    'الل',
#    'للي',
#    'بيز',
#    'يزي',
#    'زيط',
#    'يطو',
#    'طوا',
#    'الا',
#    'لاه',
#    'اهل',
#    'هلي',
#    'اتغ',
#    'تغل',
#    'غلب',
#    'اتل',
#    'تلم',
#    'لمو',
#    'موا',
#    'نرد',
#    'ردح',
#    'وشك',
#    'شكل',
#    'كلك',
#    'لكو',
#    'كوا',
#    'يبق',
#    'بقي',
#    'اكت',
#    'كتر',
#    'الزم',
#    'لزما',
#    'زمال',
#    'مالك',
#    'الكا',
#    'لكاو',
#    'كاوي',
#    'اويه',
#    'بيزي',
#    'يزيط',
#    'زيطو',
#    'يطوا',
#    'الاه',
#    'لاهل',
#    'اهلي',
#    'اتغل',
#    'تغلب',
#    'اتلم',
#    'تلمو',
#    'لموا',
#    'وشكل',
#    'شكلك',
#    'كلكو',
#    'لكوا',
#    'ال',
#    'لز',
#    'زم',
#    'ما',
#    'ال',
#    'لك',
#    'كا',
#    'او',
#    'وي',
#    'يه',
#    'ال',
#    'لل',
#    'لي',
#    'بي',
#    'يز',
#    'زي',
#    'يط',
#    'طو',
#    'وا',
#    'ال',
#    'لا',
#    'اه',
#    'هل',
#    'لي',
#    'ات',
#    'تغ',
#    'غل',
#    'لب',
#    'ات',
#    'تل',
#    'لم',
#    'مو',
#    'وا',
#    'بد',
#    'دل',
#    'نر',
#    'رد',
#    'دح',
#    'وش',
#    'شك',
#    'كل',
#    'لك',
#    'كو',
#    'وا',
#    'يب',
#    'بق',
#    'قي',
#    'وح',
#    'حش',
#    'اك',
#    'كت',
#    'تر',
#    'هو',
#    'وا'],
#   'neg'),
#  (['مش',
#    'هنخسر',
#    'حاجة',
#    'اكيد',
#    'هنخ',
#    'نخس',
#    'خسر',
#    'حاج',
#    'اجة',
#    'اكي',
#    'كيد',
#    'هنخس',
#    'نخسر',
#    'هن',
#    'نخ',
#    'خس',
#    'سر',
#    'حا',
#    'اج',
#    'جة',
#    'اك',
#    'كي',
#    'يد'],
#   'pos'),
#  (['القلم',
#    'اتكسر',
#    'ايدكو',
#    'علي',
#    'الق',
#    'لقل',
#    'قلم',
#    'اتك',
#    'تكس',
#    'كسر',
#    'ايد',
#    'يدك',
#    'دكو',
#    'القل',
#    'لقلم',
#    'اتكس',
#    'تكسر',
#    'ايدك',
#    'يدكو',
#    'ال',
#    'لق',
#    'قل',
#    'لم',
#    'ات',
#    'تك',
#    'كس',
#    'سر',
#    'اي',
#    'يد',
#    'دك',
#    'كو',
#    'عل',
#    'لي'],
#   'neg'),
#  (['ننى',
#    'أنثى',
#    'أجزم',
#    'ان',
#    'ابناء',
#    'ادم',
#    'يفهموا',
#    'قلوبنا',
#    'لة',
#    'امضواء',
#    'الف',
#    'سنه',
#    'أنث',
#    'نثى',
#    'أجز',
#    'جزم',
#    'ابن',
#    'بنا',
#    'ناء',
#    'يفه',
#    'فهم',
#    'همو',
#    'موا',
#    'قلو',
#    'لوب',
#    'وبن',
#    'بنا',
#    'امض',
#    'مضو',
#    'ضوا',
#    'واء',
#    'ابنا',
#    'بناء',
#    'يفهم',
#    'فهمو',
#    'هموا',
#    'قلوب',
#    'لوبن',
#    'وبنا',
#    'امضو',
#    'مضوا',
#    'ضواء',
#    'نن',
#    'نى',
#    'أن',
#    'نث',
#    'ثى',
#    'أج',
#    'جز',
#    'زم',
#    'اب',
#    'بن',
#    'نا',
#    'اء',
#    'اد',
#    'دم',
#    'يف',
#    'فه',
#    'هم',
#    'مو',
#    'وا',
#    'قل',
#    'لو',
#    'وب',
#    'بن',
#    'نا',
#    'ام',
#    'مض',
#    'ضو',
#    'وا',
#    'اء',
#    'ال',
#    'لف',
#    'سن',
#    'نه'],
#   'neg'),
#  (['بيقول',
#    'البص',
#    'عايزا',
#    'جزئه',
#    'يتثبت',
#    'بيق',
#    'يقو',
#    'قول',
#    'الب',
#    'لبص',
#    'عاي',
#    'ايز',
#    'يزا',
#    'جزئ',
#    'زئه',
#    'يتث',
#    'تثب',
#    'ثبت',
#    'بيقو',
#    'يقول',
#    'عايز',
#    'ايزا',
#    'يتثب',
#    'تثبت',
#    'بي',
#    'يق',
#    'قو',
#    'ول',
#    'ال',
#    'لب',
#    'بص',
#    'عا',
#    'اي',
#    'يز',
#    'زا',
#    'جز',
#    'زئ',
#    'ئه',
#    'يت',
#    'تث',
#    'ثب',
#    'بت'],
#   'neu'),
#  (['احتمالية',
#    'النواتج',
#    'ماتخلكش',
#    'ترفض',
#    'تجرب',
#    'لان',
#    'اكبد',
#    'نسبة',
#    'نجاح',
#    'حتي',
#    'صغيره',
#    'احت',
#    'حتم',
#    'تما',
#    'مال',
#    'الي',
#    'لية',
#    'الن',
#    'لنو',
#    'نوا',
#    'وات',
#    'اتج',
#    'مات',
#    'اتخ',
#    'تخل',
#    'خلك',
#    'لكش',
#    'ترف',
#    'رفض',
#    'تجر',
#    'جرب',
#    'اكب',
#    'كبد',
#    'نسب',
#    'سبة',
#    'نجا',
#    'جاح',
#    'صغي',
#    'غير',
#    'يره',
#    'احتم',
#    'حتما',
#    'تمال',
#    'مالي',
#    'الية',
#    'النو',
#    'لنوا',
#    'نوات',
#    'واتج',
#    'ماتخ',
#    'اتخل',
#    'تخلك',
#    'خلكش',
#    'صغير',
#    'غيره',
#    'اح',
#    'حت',
#    'تم',
#    'ما',
#    'ال',
#    'لي',
#    'ية',
#    'ال',
#    'لن',
#    'نو',
#    'وا',
#    'ات',
#    'تج',
#    'ما',
#    'ات',
#    'تخ',
#    'خل',
#    'لك',
#    'كش',
#    'تر',
#    'رف',
#    'فض',
#    'تج',
#    'جر',
#    'رب',
#    'لا',
#    'ان',
#    'اك',
#    'كب',
#    'بد',
#    'نس',
#    'سب',
#    'بة',
#    'نج',
#    'جا',
#    'اح',
#    'حت',
#    'تي',
#    'صغ',
#    'غي',
#    'ير',
#    'ره'],
#   'pos'),
#  (['ممكن',
#    'نتعرف',
#    'بنوته',
#    'ممك',
#    'مكن',
#    'نتع',
#    'تعر',
#    'عرف',
#    'بنو',
#    'نوت',
#    'وته',
#    'نتعر',
#    'تعرف',
#    'بنوت',
#    'نوته',
#    'مم',
#    'مك',
#    'كن',
#    'نت',
#    'تع',
#    'عر',
#    'رف',
#    'بن',
#    'نو',
#    'وت',
#    'ته'],
#   'neu'),
#  (['صعبه',
#    'تفتكر',
#    'انك',
#    'مهم',
#    'حد',
#    'وف',
#    'الاخر',
#    'تكتشف',
#    'انك',
#    'كنت',
#    'غلطان',
#    'صعب',
#    'عبه',
#    'تفت',
#    'فتك',
#    'تكر',
#    'الا',
#    'لاخ',
#    'اخر',
#    'تكت',
#    'كتش',
#    'تشف',
# ...
#    'الم',
#    'لمش',
#    'مشك',
#    'شكل',
#    'كلة',
#    'الإ',
#    'لإي',
#    'إيم',
#    'يما',
#    'مان',
#    'رؤي',
#    'ؤية',
#    'الل',
#    'لله',
#    'الق',
#    'لقا',
#    'قاد',
#    'ادر',
#    'يتع',
#    'تعا',
#    'عام',
#    'امل',
#    'الم',
#    'لمش',
#    'مشك',
#    'شكل',
#    'كلة',
#    'جوي',
#    'ويس',
#    'ماي',
#    'اير',
#    'القل',
#    'لقلق',
#    'النظ',
#    'لنظر',
#    'المش',
#    'لمشك',
#    'مشكل',
#    'شكلة',
#    'الإي',
#    'لإيم',
#    'إيما',
#    'يمان',
#    'القا',
#    'لقاد',
#    'قادر',
#    'يتعا',
#    'تعام',
#    'عامل',
#    'المش',
#    'لمشك',
#    'مشكل',
#    'شكلة',
#    'ال',
#    'لق',
#    'قل',
#    'لق',
#    'ال',
#    'لن',
#    'نظ',
#    'ظر',
#    'ال',
#    'لم',
#    'مش',
#    'شك',
#    'كل',
#    'لة',
#    'ال',
#    'لإ',
#    'إي',
#    'يم',
#    'ما',
#    'ان',
#    'فه',
#    'هو',
#    'رؤ',
#    'ؤي',
#    'ية',
#    'ال',
#    'لل',
#    'له',
#    'ال',
#    'لق',
#    'قا',
#    'اد',
#    'در',
#    'يت',
#    'تع',
#    'عا',
#    'ام',
#    'مل',
#    'ال',
#    'لم',
#    'مش',
#    'شك',
#    'كل',
#    'لة',
#    'جو',
#    'وي',
#    'يس',
#    'ما',
#    'اي',
#    'ير'],
#   'pos'),
#  (['آذان',
#    'العصر',
#    'آذا',
#    'ذان',
#    'الع',
#    'لعص',
#    'عصر',
#    'العص',
#    'لعصر',
#    'آذ',
#    'ذا',
#    'ان',
#    'ال',
#    'لع',
#    'عص',
#    'صر'],
#   'neu'),
#  (['النادي',
#    'الأهلي',
#    'دا',
#    'فريق',
#    'جبار',
#    'زى',
#    'الاعصار',
#    'ولعها',
#    'نار',
#    'الن',
#    'لنا',
#    'ناد',
#    'ادي',
#    'الأ',
#    'لأه',
#    'أهل',
#    'هلي',
#    'فري',
#    'ريق',
#    'جبا',
#    'بار',
#    'الا',
#    'لاع',
#    'اعص',
#    'عصا',
#    'صار',
#    'ولع',
#    'لعه',
#    'عها',
#    'النا',
#    'لناد',
#    'نادي',
#    'الأه',
#    'لأهل',
#    'أهلي',
#    'الاع',
#    'لاعص',
#    'اعصا',
#    'عصار',
#    'ولعه',
#    'لعها',
#    'ال',
#    'لن',
#    'نا',
#    'اد',
#    'دي',
#    'ال',
#    'لأ',
#    'أه',
#    'هل',
#    'لي',
#    'فر',
#    'ري',
#    'يق',
#    'جب',
#    'با',
#    'ار',
#    'ال',
#    'لا',
#    'اع',
#    'عص',
#    'صا',
#    'ار',
#    'ول',
#    'لع',
#    'عه',
#    'ها',
#    'نا',
#    'ار'],
#   'pos'),
#  (['بسالوا',
#    'الناس',
#    'امتحان',
#    'اليوم',
#    'بجيك',
#    'عرص',
#    'رسبت',
#    'علامتين',
#    'يفضح',
#    'عرضك',
#    'انت',
#    'الثاني',
#    'صرت',
#    'عارف',
#    'بسا',
#    'سال',
#    'الو',
#    'لوا',
#    'الن',
#    'لنا',
#    'ناس',
#    'امت',
#    'متح',
#    'تحا',
#    'حان',
#    'الي',
#    'ليو',
#    'يوم',
#    'بجي',
#    'جيك',
#    'رسب',
#    'سبت',
#    'علا',
#    'لام',
#    'امت',
#    'متي',
#    'تين',
#    'يفض',
#    'فضح',
#    'عرض',
#    'رضك',
#    'الث',
#    'لثا',
#    'ثان',
#    'اني',
#    'عار',
#    'ارف',
#    'بسال',
#    'سالو',
#    'الوا',
#    'النا',
#    'لناس',
#    'امتح',
#    'متحا',
#    'تحان',
#    'اليو',
#    'ليوم',
#    'علام',
#    'لامت',
#    'امتي',
#    'متين',
#    'الثا',
#    'لثان',
#    'ثاني',
#    'بس',
#    'سا',
#    'ال',
#    'لو',
#    'وا',
#    'ال',
#    'لن',
#    'نا',
#    'اس',
#    'ام',
#    'مت',
#    'تح',
#    'حا',
#    'ان',
#    'ال',
#    'لي',
#    'يو',
#    'وم',
#    'بج',
#    'جي',
#    'يك',
#    'عر',
#    'رص',
#    'رس',
#    'سب',
#    'بت',
#    'عل',
#    'لا',
#    'ام',
#    'مت',
#    'تي',
#    'ين',
#    'يف',
#    'فض',
#    'ضح',
#    'عر',
#    'رض',
#    'ضك',
#    'ان',
#    'نت',
#    'ال',
#    'لث',
#    'ثا',
#    'ان',
#    'ني',
#    'صر',
#    'رت',
#    'عا',
#    'ار',
#    'رف'],
#   'neg'),
#  (['انا',
#    'عيز',
#    'اتعرف',
#    'عليكي',
#    'اتع',
#    'تعر',
#    'عرف',
#    'علي',
#    'ليك',
#    'يكي',
#    'اتعر',
#    'تعرف',
#    'عليك',
#    'ليكي',
#    'ان',
#    'نا',
#    'عي',
#    'يز',
#    'ات',
#    'تع',
#    'عر',
#    'رف',
#    'عل',
#    'لي',
#    'يك',
#    'كي'],
#   'pos'),
#  (['كنت',
#    'هموت',
#    'امبارح',
#    'واعرف',
#    'شويه',
#    'بيوشوشوا',
#    'يقولوا',
#    'ايه',
#    'يلا',
#    'منك',
#    'لله',
#    'كنترول',
#    'همو',
#    'موت',
#    'امب',
#    'مبا',
#    'بار',
#    'ارح',
#    'واع',
#    'اعر',
#    'عرف',
#    'شوي',
#    'ويه',
#    'بيو',
#    'يوش',
#    'وشو',
#    'شوش',
#    'وشو',
#    'شوا',
#    'يقو',
#    'قول',
#    'ولو',
#    'لوا',
#    'كنت',
#    'نتر',
#    'ترو',
#    'رول',
#    'امبا',
#    'مبار',
#    'بارح',
#    'واعر',
#    'اعرف',
#    'بيوش',
#    'يوشو',
#    'وشوش',
#    'شوشو',
#    'وشوا',
#    'يقول',
#    'قولو',
#    'ولوا',
#    'كنتر',
#    'نترو',
#    'ترول',
#    'كن',
#    'نت',
#    'هم',
#    'مو',
#    'وت',
#    'ام',
#    'مب',
#    'با',
#    'ار',
#    'رح',
#    'وا',
#    'اع',
#    'عر',
#    'رف',
#    'شو',
#    'وي',
#    'يه',
#    'بي',
#    'يو',
#    'وش',
#    'شو',
#    'وش',
#    'شو',
#    'وا',
#    'يق',
#    'قو',
#    'ول',
#    'لو',
#    'وا',
#    'اي',
#    'يه',
#    'يل',
#    'لا',
#    'من',
#    'نك',
#    'لل',
#    'له',
#    'كن',
#    'نت',
#    'تر',
#    'رو',
#    'ول'],
#   'neg'),
#  (['عام',
#    'وانتم',
#    'بخير',
#    'وان',
#    'انت',
#    'نتم',
#    'بخي',
#    'خير',
#    'وانت',
#    'انتم',
#    'عا',
#    'ام',
#    'وا',
#    'ان',
#    'نت',
#    'تم',
#    'بخ',
#    'خي',
#    'ير'],
#   'pos'),
#  (['اوساخ',
#    'والله',
#    'انا',
#    'كنت',
#    'جاي',
#    'اوس',
#    'وسا',
#    'ساخ',
#    'وال',
#    'الل',
#    'لله',
#    'اوسا',
#    'وساخ',
#    'والل',
#    'الله',
#    'او',
#    'وس',
#    'سا',
#    'اخ',
#    'وا',
#    'ال',
#    'لل',
#    'له',
#    'ان',
#    'نا',
#    'كن',
#    'نت',
#    'جا',
#    'اي'],
#   'neg'),
#  (['الورد',
#    'جميعا',
#    'مدينة',
#    'الشيخ',
#    'زايد',
#    'الو',
#    'لور',
#    'ورد',
#    'جمي',
#    'ميع',
#    'يعا',
#    'مدي',
#    'دين',
#    'ينة',
#    'الش',
#    'لشي',
#    'شيخ',
#    'زاي',
#    'ايد',
#    'الور',
#    'لورد',
#    'جميع',
#    'ميعا',
#    'مدين',
#    'دينة',
#    'الشي',
#    'لشيخ',
#    'ال',
#    'لو',
#    'ور',
#    'رد',
#    'جم',
#    'مي',
#    'يع',
#    'عا',
#    'مد',
#    'دي',
#    'ين',
#    'نة',
#    'ال',
#    'لش',
#    'شي',
#    'يخ',
#    'زا',
#    'اي',
#    'يد'],
#   'pos'),
#  (['شكرا',
#    'لأنك',
#    'حياتي',
#    'شكرا',
#    'لأنك',
#    'حياتي',
#    'الحب',
#    'شكر',
#    'كرا',
#    'لأن',
#    'أنك',
#    'حيا',
#    'يات',
#    'اتي',
#    'شكر',
#    'كرا',
#    'لأن',
#    'أنك',
#    'حيا',
#    'يات',
#    'اتي',
#    'الح',
#    'لحب',
#    'حيات',
#    'ياتي',
#    'حيات',
#    'ياتي',
#    'شك',
#    'كر',
#    'را',
#    'لأ',
#    'أن',
#    'نك',
#    'حي',
#    'يا',
#    'ات',
#    'تي',
#    'شك',
#    'كر',
#    'را',
#    'لأ',
#    'أن',
#    'نك',
#    'حي',
#    'يا',
#    'ات',
#    'تي',
#    'ال',
#    'لح',
#    'حب'],
#   'pos'),
#  (['حزن', 'حزن', 'حز', 'زن', 'حز', 'زن'], 'neg'),
#  (['تجيبي',
#    'الايفون',
#    'حبا',
#    'تجي',
#    'جيب',
#    'يبي',
#    'الا',
#    'لاي',
#    'ايف',
#    'يفو',
#    'فون',
#    'تجيب',
#    'جيبي',
#    'الاي',
#    'لايف',
#    'ايفو',
#    'يفون',
#    'تج',
#    'جي',
#    'يب',
#    'بي',
#    'ال',
#    'لا',
#    'اي',
#    'يف',
#    'فو',
#    'ون',
#    'حب',
#    'با'],
#   'neu'),
#  (['اللهم',
#    'أجرني',
#    'مصيبتي',
#    'وأخلف',
#    'خيرا',
#    'الل',
#    'لله',
#    'لهم',
#    'أجر',
#    'جرن',
#    'رني',
#    'مصي',
#    'صيب',
#    'يبت',
#    'بتي',
#    'وأخ',
#    'أخل',
#    'خلف',
#    'خير',
#    'يرا',
#    'الله',
#    'للهم',
#    'أجرن',
#    'جرني',
#    'مصيب',
#    'صيبت',
#    'يبتي',
#    'وأخل',
#    'أخلف',
#    'ال',
#    'لل',
#    'له',
#    'هم',
#    'أج',
#    'جر',
#    'رن',
#    'ني',
#    'مص',
#    'صي',
#    'يب',
#    'بت',
#    'تي',
#    'وأ',
#    'أخ',
#    'خل',
#    'لف',
#    'خي',
#    'ير',
#    'را'],
#   'neg'),
#  (['وانتي',
#    'نورتيني',
#    'وان',
#    'انت',
#    'نتي',
#    'نور',
#    'ورت',
#    'رتي',
#    'تين',
#    'يني',
#    'وانت',
#    'انتي',
#    'نورت',
#    'ورتي',
#    'رتين',
#    'تيني',
#    'وا',
#    'ان',
#    'نت',
#    'تي',
#    'نو',
#    'ور',
#    'رت',
#    'تي',
#    'ين',
#    'ني'],
#   'pos'),
#  (['إختصروا',
#    'الطريق',
#    'بدلا',
#    'إختيار',
#    'المنصف',
#    'الانقلاب',
#    'يبدو',
#    'الدولة',
#    'العميقة',
#    'ضاربة',
#    'بجذورها',
#    'فى',
#    'دول',
#    'العالم',
#    'النامى',
#    'كله',
#    'إخت',
#    'ختص',
#    'تصر',
#    'صرو',
#    'روا',
#    'الط',
#    'لطر',
#    'طري',
#    'ريق',
#    'بدل',
#    'دلا',
#    'إخت',
#    'ختي',
#    'تيا',
#    'يار',
#    'الم',
#    'لمن',
#    'منص',
#    'نصف',
#    'الا',
#    'لان',
#    'انق',
#    'نقل',
#    'قلا',
#    'لاب',
#    'يبد',
#    'بدو',
#    'الد',
#    'لدو',
#    'دول',
#    'ولة',
#    'الع',
#    'لعم',
#    'عمي',
#    'ميق',
#    'يقة',
#    'ضار',
#    'ارب',
#    'ربة',
#    'بجذ',
#    'جذو',
#    'ذور',
#    'وره',
#    'رها',
#    'الع',
#    'لعا',
#    'عال',
#    'الم',
#    'الن',
#    'لنا',
#    'نام',
#    'امى',
#    'إختص',
#    'ختصر',
#    'تصرو',
#    'صروا',
#    'الطر',
#    'لطري',
#    'طريق',
#    'إختي',
#    'ختيا',
#    'تيار',
#    'المن',
#    'لمنص',
#    'منصف',
#    'الان',
#    'لانق',
#    'انقل',
#    'نقلا',
#    'قلاب',
#    'الدو',
#    'لدول',
#    'دولة',
#    'العم',
#    'لعمي',
#    'عميق',
#    'ميقة',
#    'ضارب',
#    'اربة',
#    'بجذو',
#    'جذور',
#    'ذوره',
#    'ورها',
#    'العا',
#    'لعال',
#    'عالم',
#    'النا',
#    'لنام',
#    'نامى',
#    'إخ',
#    'خت',
#    'تص',
#    'صر',
#    'رو',
#    'وا',
#    'ال',
#    'لط',
#    'طر',
#    'ري',
#    'يق',
#    'بد',
#    'دل',
#    'لا',
#    'إخ',
#    'خت',
#    'تي',
#    'يا',
#    'ار',
#    'ال',
#    'لم',
#    'من',
#    'نص',
#    'صف',
#    'ال',
#    'لا',
#    'ان',
#    'نق',
#    'قل',
#    'لا',
#    'اب',
#    'يب',
#    'بد',
#    'دو',
#    'ال',
#    'لد',
#    'دو',
#    'ول',
#    'لة',
#    'ال',
#    'لع',
#    'عم',
#    'مي',
#    'يق',
#    'قة',
#    'ضا',
#    'ار',
#    'رب',
#    'بة',
#    'بج',
#    'جذ',
#    'ذو',
#    'ور',
#    'ره',
#    'ها',
#    'دو',
#    'ول',
#    'ال',
#    'لع',
#    'عا',
#    'ال',
#    'لم',
#    'ال',
#    'لن',
#    'نا',
#    'ام',
#    'مى',
#    'كل',
#    'له'],
#   'neg'),
#  (['مشكلتنا',
#    'ان',
#    'احنا',
#    'عاملين',
#    'نفسنا',
#    'فاهمين',
#    'الدين',
#    'صح',
#    'مش',
#    'عارفين',
#    'اننا',
#    'حاولنا',
#    'حتي',
#    'نفهم',
#    'مش',
#    'هيكون',
#    'دا',
#    'حالنا',
#    'ربي',
#    'اصلح',
#    'شان',
#    'الامة',
#    'مشك',
#    'شكل',
#    'كلت',
#    'لتن',
#    'تنا',
#    'احن',
#    'حنا',
#    'عام',
#    'امل',
#    'ملي',
#    'لين',
#    'نفس',
#    'فسن',
#    'سنا',
#    'فاه',
#    'اهم',
#    'همي',
#    'مين',
#    'الد',
#    'لدي',
#    'دين',
#    'عار',
#    'ارف',
#    'رفي',
#    'فين',
#    'انن',
#    'ننا',
#    'حاو',
#    'اول',
#    'ولن',
#    'لنا',
#    'نفه',
#    'فهم',
#    'هيك',
#    'يكو',
#    'كون',
#    'حال',
#    'الن',
#    'لنا',
#    'اصل',
#    'صلح',
#    'الا',
#    'لام',
#    'امة',
#    'مشكل',
#    'شكلت',
#    'كلتن',
#    'لتنا',
#    'عامل',
#    'املي',
#    'ملين',
#    'نفسن',
#    'فسنا',
#    'فاهم',
#    'اهمي',
#    'همين',
#    'الدي',
#    'لدين',
#    'عارف',
#    'ارفي',
#    'رفين',
#    'حاول',
#    'اولن',
#    'ولنا',
#    'هيكو',
#    'يكون',
#    'حالن',
#    'النا',
#    'الام',
#    'لامة',
#    'مش',
#    'شك',
#    'كل',
#    'لت',
#    'تن',
#    'نا',
#    'اح',
#    'حن',
#    'نا',
#    'عا',
#    'ام',
#    'مل',
#    'لي',
#    'ين',
#    'نف',
#    'فس',
#    'سن',
#    'نا',
#    'فا',
#    'اه',
#    'هم',
#    'مي',
#    'ين',
#    'ال',
#    'لد',
#    'دي',
#    'ين',
#    'عا',
#    'ار',
#    'رف',
#    'في',
#    'ين',
#    'ان',
#    'نن',
#    'نا',
#    'حا',
#    'او',
#    'ول',
#    'لن',
#    'نا',
#    'حت',
#    'تي',
#    'نف',
#    'فه',
#    'هم',
#    'هي',
#    'يك',
#    'كو',
#    'ون',
#    'حا',
#    'ال',
#    'لن',
#    'نا',
#    'رب',
#    'بي',
#    'اص',
#    'صل',
#    'لح',
#    'شا',
#    'ان',
#    'ال',
#    'لا',
#    'ام',
#    'مة'],
#   'neg'),
#  (['الشيء',
#    'المميز',
#    'خالد',
#    'بن',
#    'سعد',
#    'انه',
#    'مايهايط',
#    'انسان',
#    'متواضع',
#    'وواضح',
#    'جماهير',
#    'ناديه',
#    'سياسته',
#    'واقعية',
#    'اعطوه',
#    'الثقة',
#    'وادعموه',
#    'ولن',
#    'تندموا',
#    'الش',
#    'لشي',
#    'شيء',
#    'الم',
#    'لمم',
#    'ممي',
#    'ميز',
#    'خال',
#    'الد',
#    'ماي',
#    'ايه',
#    'يها',
#    'هاي',
#    'ايط',
#    'انس',
#    'نسا',
#    'سان',
#    'متو',
#    'توا',
#    'واض',
#    'اضع',
#    'ووا',
#    'واض',
#    'اضح',
#    'جما',
#    'ماه',
#    'اهي',
#    'هير',
#    'ناد',
#    'ادي',
#    'ديه',
#    'سيا',
#    'ياس',
#    'است',
#    'سته',
#    'واق',
#    'اقع',
#    'قعي',
#    'عية',
#    'اعط',
#    'عطو',
#    'طوه',
#    'الث',
#    'لثق',
#    'ثقة',
#    'واد',
#    'ادع',
#    'دعم',
#    'عمو',
#    'موه',
#    'تند',
#    'ندم',
#    'دمو',
#    'موا',
#    'الشي',
#    'لشيء',
#    'المم',
#    'لممي',
#    'مميز',
#    'مايه',
#    'ايها',
#    'يهاي',
#    'هايط',
#    'انسا',
#    'نسان',
#    'متوا',
#    'تواض',
#    'واضع',
#    'وواض',
#    'واضح',
#    'جماه',
#    'ماهي',
#    'اهير',
#    'نادي',
#    'اديه',
#    'سياس',
#    'ياست',
#    'استه',
#    'واقع',
#    'اقعي',
#    'قعية',
#    'اعطو',
#    'عطوه',
#    'الثق',
#    'لثقة',
#    'وادع',
#    'ادعم',
#    'دعمو',
#    'عموه',
#    'تندم',
#    'ندمو',
#    'دموا',
#    'ال',
#    'لش',
#    'شي',
#    'يء',
#    'ال',
#    'لم',
#    'مم',
#    'مي',
#    'يز',
#    'خا',
#    'ال',
#    'لد',
#    'سع',
#    'عد',
#    'ان',
#    'نه',
#    'ما',
#    'اي',
#    'يه',
#    'ها',
#    'اي',
#    'يط',
#    'ان',
#    'نس',
#    'سا',
#    'ان',
#    'مت',
#    'تو',
#    'وا',
#    'اض',
#    'ضع',
#    'وو',
#    'وا',
#    'اض',
#    'ضح',
#    'جم',
#    'ما',
#    'اه',
#    'هي',
#    'ير',
#    'نا',
#    'اد',
#    'دي',
#    'يه',
#    'سي',
#    'يا',
#    'اس',
#    'ست',
#    'ته',
#    'وا',
#    'اق',
#    'قع',
#    'عي',
#    'ية',
#    'اع',
#    'عط',
#    'طو',
#    'وه',
#    'ال',
#    'لث',
#    'ثق',
#    'قة',
#    'وا',
#    'اد',
#    'دع',
#    'عم',
#    'مو',
#    'وه',
#    'ول',
#    'لن',
#    'تن',
#    'ند',
#    'دم',
#    'مو',
#    'وا'],
#   'pos'),
#  (['الجسر',
#    'ذكرى',
#    'المولد',
#    'للتمسك',
#    'بنهج',
#    'الرسول',
#    'الج',
#    'لجس',
#    'جسر',
#    'ذكر',
#    'كرى',
#    'الم',
#    'لمو',
#    'مول',
#    'ولد',
#    'للت',
#    'لتم',
#    'تمس',
#    'مسك',
#    'بنه',
#    'نهج',
#    'الر',
#    'لرس',
#    'رسو',
#    'سول',
#    'الجس',
#    'لجسر',
#    'المو',
#    'لمول',
#    'مولد',
#    'للتم',
#    'لتمس',
#    'تمسك',
#    'الرس',
#    'لرسو',
#    'رسول',
#    'ال',
#    'لج',
#    'جس',
#    'سر',
#    'ذك',
#    'كر',
#    'رى',
#    'ال',
#    'لم',
#    'مو',
#    'ول',
#    'لد',
#    'لل',
#    'لت',
#    'تم',
#    'مس',
#    'سك',
#    'بن',
#    'نه',
#    'هج',
#    'ال',
#    'لر',
#    'رس',
#    'سو',
#    'ول'],
#   'pos'),
#  (['وحضرتك',
#    'بألف',
#    'صحة',
#    'وخير',
#    'وكل',
#    'أيامك',
#    'فرحة',
#    'وحض',
#    'حضر',
#    'ضرت',
#    'رتك',
#    'بأل',
#    'ألف',
#    'وخي',
#    'خير',
#    'أيا',
#    'يام',
#    'امك',
#    'فرح',
#    'رحة',
#    'وحضر',
#    'حضرت',
#    'ضرتك',
#    'أيام',
#    'يامك',
#    'وح',
#    'حض',
#    'ضر',
#    'رت',
#    'تك',
#    'بأ',
#    'أل',
#    'لف',
#    'صح',
#    'حة',
#    'وخ',
#    'خي',
#    'ير',
#    'وك',
#    'كل',
#    'أي',
#    'يا',
#    'ام',
#    'مك',
#    'فر',
#    'رح',
#    'حة'],
#   'pos'),
#  (['تجوم',
#    'تطمن',
#    'مؤمن',
#    'مؤمن',
#    'زكريا',
#    'الزمالك',
#    'ان',
#    'شاء',
#    'الله',
#    'مؤمن',
#    'السيطرة',
#    'الزملكاوية',
#    'تجو',
#    'جوم',
#    'تطم',
#    'طمن',
#    'مؤم',
#    'ؤمن',
#    'مؤم',
#    'ؤمن',
#    'زكر',
#    'كري',
#    'ريا',
#    'الز',
#    'لزم',
#    'زما',
#    'مال',
#    'الك',
#    'الل',
#    'لله',
#    'مؤم',
#    'ؤمن',
#    'الس',
#    'لسي',
#    'سيط',
#    'يطر',
#    'طرة',
#    'الز',
#    'لزم',
#    'زمل',
#    'ملك',
#    'لكا',
#    'كاو',
#    'اوي',
#    'وية',
#    'زكري',
#    'كريا',
#    'الزم',
#    'لزما',
#    'زمال',
#    'مالك',
#    'السي',
#    'لسيط',
#    'سيطر',
#    'يطرة',
#    'الزم',
#    'لزمل',
#    'زملك',
#    'ملكا',
#    'لكاو',
#    'كاوي',
#    'اوية',
#    'تج',
#    'جو',
#    'وم',
#    'تط',
#    'طم',
#    'من',
#    'مؤ',
#    'ؤم',
#    'من',
#    'مؤ',
#    'ؤم',
#    'من',
#    'زك',
#    'كر',
#    'ري',
#    'يا',
#    'ال',
#    'لز',
#    'زم',
#    'ما',
#    'ال',
#    'لك',
#    'شا',
#    'اء',
#    'ال',
#    'لل',
#    'له',
#    'مؤ',
#    'ؤم',
#    'من',
#    'ال',
#    'لس',
#    'سي',
#    'يط',
#    'طر',
#    'رة',
#    'ال',
#    'لز',
#    'زم',
#    'مل',
#    'لك',
#    'كا',
#    'او',
#    'وي',
#    'ية'],
#   'neu'),
#  (['فكرة',
#    'اني',
#    'هصلح',
#    'العجله',
#    'انزل',
#    'بيها',
#    'الاجازه',
#    'صاحبي',
#    'مسيطره',
#    'عليا',
#    'الصبح',
#    'فرحان',
#    'العيد',
#    'بكره',
#    'الواحد',
#    'اتهبل',
#    'والله',
#    'فكر',
#    'كرة',
#    'هصل',
#    'صلح',
#    'الع',
#    'لعج',
#    'عجل',
#    'جله',
#    'انز',
#    'نزل',
#    'بيه',
#    'يها',
#    'الا',
#    'لاج',
#    'اجا',
#    'جاز',
#    'ازه',
#    'صاح',
#    'احب',
#    'حبي',
#    'مسي',
#    'سيط',
#    'يطر',
#    'طره',
#    'علي',
#    'ليا',
#    'الص',
#    'لصب',
#    'صبح',
#    'فرح',
#    'رحا',
#    'حان',
#    'الع',
#    'لعي',
#    'عيد',
#    'بكر',
#    'كره',
#    'الو',
#    'لوا',
#    'واح',
#    'احد',
#    'اته',
#    'تهب',
#    'هبل',
#    'وال',
#    'الل',
#    'لله',
#    'العج',
#    'لعجل',
#    'عجله',
#    'الاج',
#    'لاجا',
#    'اجاز',
#    'جازه',
#    'صاحب',
#    'احبي',
#    'مسيط',
#    'سيطر',
#    'يطره',
#    'الصب',
#    'لصبح',
#    'فرحا',
#    'رحان',
#    'العي',
#    'لعيد',
#    'الوا',
#    'لواح',
#    'واحد',
#    'اتهب',
#    'تهبل',
#    'والل',
#    'الله',
#    'فك',
#    'كر',
#    'رة',
#    'ان',
#    'ني',
#    'هص',
#    'صل',
#    'لح',
#    'ال',
#    'لع',
#    'عج',
#    'جل',
#    'له',
#    'ان',
#    'نز',
#    'زل',
#    'بي',
#    'يه',
#    'ها',
#    'ال',
#    'لا',
#    'اج',
#    'جا',
#    'از',
#    'زه',
#    'صا',
#    'اح',
#    'حب',
#    'بي',
#    'مس',
#    'سي',
#    'يط',
#    'طر',
#    'ره',
#    'عل',
#    'لي',
#    'يا',
#    'ال',
#    'لص',
#    'صب',
#    'بح',
#    'فر',
#    'رح',
#    'حا',
#    'ان',
#    'ال',
#    'لع',
#    'عي',
#    'يد',
#    'بك',
#    'كر',
#    'ره',
#    'ال',
#    'لو',
#    'وا',
#    'اح',
#    'حد',
#    'ات',
#    'ته',
#    'هب',
#    'بل',
#    'وا',
#    'ال',
#    'لل',
#    'له'],
#   'pos'),
#  (['ربـ',
#    'ساترها',
#    'الناس',
#    'سات',
#    'اتر',
#    'تره',
#    'رها',
#    'الن',
#    'لنا',
#    'ناس',
#    'ساتر',
#    'اتره',
#    'ترها',
#    'النا',
#    'لناس',
#    'رب',
#    'بـ',
#    'سا',
#    'ات',
#    'تر',
#    'ره',
#    'ها',
#    'ال',
#    'لن',
#    'نا',
#    'اس'],
#   'neu')]

# %% [markdown]
# # Sample training data

# %%
import random
sample_size = 100
print('{} random tweets .... '.format(sample_size))
for s in random.sample(train_data, sample_size):
    print(s)
# Out:
# 100 random tweets ....
# (['الباقي', 'الزبالة', 'الب', 'لبا', 'باق', 'اقي', 'الز', 'لزب', 'زبا', 'بال', 'الة', 'البا', 'لباق', 'باقي', 'الزب', 'لزبا', 'زبال', 'بالة', 'ال', 'لب', 'با', 'اق', 'قي', 'ال', 'لز', 'زب', 'با', 'ال', 'لة'], 'neg')
ن', 'لفنى', 'فر', 'ري', 'يق', 'دم', 'من', 'نه', 'هو', 'ور', 'يس', 'ست', 'تأ', 'أن', 'نف', 'اس', 'ست', 'تع', 'عد', 'دا', 'اد', 'دا', 'ات', 'ته', 'لم', 'مو', 'وا', 'اج', 'جه', 'هة', 'ال', 'لز', 'زم', 'ما', 'ال', 'لك', 'ال', 'لا', 'اث', 'ثن', 'ني', 'ين', 'قي', 'يا', 'اد', 'دة', 'مد', 'دي', 'ير', 'ره', 'ال', 'لف', 'فن', 'نى', 'مح', 'حم', 'مد', 'عم', 'مر'], 'neu')
# (['أد', 'افاتارك', 'هيكون', 'الحك', 'معاكي', 'احترمي', 'نفسك', 'الاول', 'ومحدش', 'هيجي', 'جنبك', 'سامع', 'صوت', 'بيقول', 'الافاتار', 'حرية', 'شحصية', 'والحك', 'برده', 'حرية', 'شخصية', 'افا', 'فات', 'اتا', 'تار', 'ارك', 'هيك', 'يكو', 'كون', 'الح', 'لحك', 'معا', 'عاك', 'اكي', 'احت', 'حتر', 'ترم', 'رمي', 'نفس', 'فسك', 'الا', 'لاو', 'اول', 'ومح', 'محد', 'حدش', 'هيج', 'يجي', 'جنب', 'نبك', 'سام', 'امع', 'بيق', 'يقو', 'قول', 'الا', 'لاف', 'افا', 'فات', 'اتا', 'تار', 'حري', 'رية', 'شحص', 'حصي', 'صية', 'وال', 'الح', 'لحك', 'برد', 'رده', 'حري', 'رية', 'شخص', 'خصي', 'صية', 'افات', 'فاتا', 'اتار', 'تارك', 'هيكو', 'يكون', 'معاك', 'عاكي', 'احتر', 'حترم', 'ترمي', 'الاو', 'لاول', 'ومحد', 'محدش', 'بيقو', 'يقول', 'الاف', 'لافا', 'افات', 'فاتا', 'اتار', 'شحصي', 'حصية', 'والح', 'الحك', 'شخصي', 'خصية', 'اف', 'فا', 'ات', 'تا', 'ار', 'رك', 'هي', 'يك', 'كو', 'ون', 'ال', 'لح', 'حك', 'مع', 'عا', 'اك', 'كي', 'اح', 'حت', 'تر', 'رم', 'مي', 'نف', 'فس', 'سك', 'ال', 'لا', 'او', 'ول', 'وم', 'مح', 'حد', 'دش', 'هي', 'يج', 'جي', 'جن', 'نب', 'بك', 'سا', 'ام', 'مع', 'صو', 'وت', 'بي', 'يق', 'قو', 'ول', 'ال', 'لا', 'اف', 'فا', 'ات', 'تا', 'ار', 'حر', 'ري', 'ية', 'شح', 'حص', 'صي', 'ية', 'وا', 'ال', 'لح', 'حك', 'بر', 'رد', 'ده', 'حر', 'ري', 'ية', 'شخ', 'خص', 'صي', 'ية'], 'neg')
# (['توكلناا', 'الله', 'يارب', 'يامعين', 'توك', 'وكل', 'كلن', 'لنا', 'ناا', 'الل', 'لله', 'يار', 'ارب', 'يام', 'امع', 'معي', 'عين', 'توكل', 'وكلن', 'كلنا', 'لناا', 'يامع', 'امعي', 'معين', 'تو', 'وك', 'كل', 'لن', 'نا', 'اا', 'ال', 'لل', 'له', 'يا', 'ار', 'رب', 'يا', 'ام', 'مع', 'عي', 'ين'], 'pos')
# (['ولأنها', 'شرقية', 'تستغرب', 'قتلها', 'الحنين', 'ولن', 'تأتي', 'ولأ', 'لأن', 'أنه', 'نها', 'شرق', 'رقي', 'قية', 'تست', 'ستغ', 'تغر', 'غرب', 'قتل', 'تله', 'لها', 'الح', 'لحن', 'حني', 'نين', 'تأت', 'أتي', 'ولأن', 'لأنه', 'أنها', 'شرقي', 'رقية', 'تستغ', 'ستغر', 'تغرب', 'قتله', 'تلها', 'الحن', 'لحني', 'حنين', 'ول', 'لأ', 'أن', 'نه', 'ها', 'شر', 'رق', 'قي', 'ية', 'تس', 'ست', 'تغ', 'غر', 'رب', 'قت', 'تل', 'له', 'ها', 'ال', 'لح', 'حن', 'ني', 'ين', 'ول', 'لن', 'تأ', 'أت', 'تي'], 'neg')
# (['العب', 'اخضر', 'الع', 'لعب', 'اخض', 'خضر', 'ال', 'لع', 'عب', 'اخ', 'خض', 'ضر'], 'pos')
# (['اكيد', 'طبعا', 'شرف', 'ليكم', 'خدم', 'الزوبر', 'اكي', 'كيد', 'طبع', 'بعا', 'ليك', 'يكم', 'الز', 'لزو', 'زوب', 'وبر', 'الزو', 'لزوب', 'زوبر', 'اك', 'كي', 'يد', 'طب', 'بع', 'عا', 'شر', 'رف', 'لي', 'يك', 'كم', 'خد', 'دم', 'ال', 'لز', 'زو', 'وب', 'بر'], 'neg')
# (['يأتيك', 'البرد', 'تعلم', 'يأت', 'أتي', 'تيك', 'الب', 'لبر', 'برد', 'تعل', 'علم', 'يأتي', 'أتيك', 'البر', 'لبرد', 'يأ', 'أت', 'تي', 'يك', 'ال', 'لب', 'بر', 'رد', 'تع', 'عل', 'لم'], 'neg')
# (['تتحقق', 'أحلامك', 'ماتنساش', 'تدفع', 'ديونك', 'القديمة', 'تتح', 'تحق', 'حقق', 'أحل', 'حلا', 'لام', 'امك', 'مات', 'اتن', 'تنس', 'نسا', 'ساش', 'تدف', 'دفع', 'ديو', 'يون', 'ونك', 'الق', 'لقد', 'قدي', 'ديم', 'يمة', 'تتحق', 'تحقق', 'أحلا', 'حلام', 'لامك', 'ماتن', 'اتنس', 'تنسا', 'نساش', 'ديون', 'يونك', 'القد', 'لقدي', 'قديم', 'ديمة', 'تت', 'تح', 'حق', 'قق', 'أح', 'حل', 'لا', 'ام', 'مك', 'ما', 'ات', 'تن', 'نس', 'سا', 'اش', 'تد', 'دف', 'فع', 'دي', 'يو', 'ون', 'نك', 'ال', 'لق', 'قد', 'دي', 'يم', 'مة'], 'neu')
# (['عام', 'شكرا', 'روح', 'لامك', 'سنه', 'كانت', 'مفكرا', 'نفسها', 'شكر', 'كرا', 'لام', 'امك', 'كان', 'انت', 'مفك', 'فكر', 'كرا', 'نفس', 'فسه', 'سها', 'مفكر', 'فكرا', 'نفسه', 'فسها', 'عا', 'ام', 'شك', 'كر', 'را', 'رو', 'وح', 'لا', 'ام', 'مك', 'سن', 'نه', 'كا', 'ان', 'نت', 'مف', 'فك', 'كر', 'را', 'نف', 'فس', 'سه', 'ها'], 'neg')
# (['مش', 'لازم', 'القريبين', 'منك', 'يعرفوا', 'كبيرة', 'وصغيرة', 'عنك', 'حاجات', 'لازم', 'تحتفظ', 'بيها', 'لنفسك', 'لاز', 'ازم', 'الق', 'لقر', 'قري', 'ريب', 'يبي', 'بين', 'يعر', 'عرف', 'رفو', 'فوا', 'كبي', 'بير', 'يرة', 'وصغ', 'صغي', 'غير', 'يرة', 'حاج', 'اجا', 'جات', 'لاز', 'ازم', 'تحت', 'حتف', 'تفظ', 'بيه', 'يها', 'لنف', 'نفس', 'فسك', 'القر', 'لقري', 'قريب', 'ريبي', 'يبين', 'يعرف', 'عرفو', 'رفوا', 'كبير', 'بيرة', 'وصغي', 'صغير', 'غيرة', 'حاجا', 'اجات', 'تحتف', 'حتفظ', 'لنفس', 'نفسك', 'لا', 'از', 'زم', 'ال', 'لق', 'قر', 'ري', 'يب', 'بي', 'ين', 'من', 'نك', 'يع', 'عر', 'رف', 'فو', 'وا', 'كب', 'بي', 'ير', 'رة', 'وص', 'صغ', 'غي', 'ير', 'رة', 'عن', 'نك', 'حا', 'اج', 'جا', 'ات', 'لا', 'از', 'زم', 'تح', 'حت', 'تف', 'فظ', 'بي', 'يه', 'ها', 'لن', 'نف', 'فس', 'سك'], 'neu')
# (['ولعها', 'واخربها', 'يامينو', 'اخر', 'يوم', 'ولما', 'ترجع', 'هاتولع', 'اكتر', 'عشقى', 'للصوره', 'دى', 'ولع', 'لعه', 'عها', 'واخ', 'اخر', 'خرب', 'ربه', 'بها', 'يام', 'امي', 'مين', 'ينو', 'ولم', 'لما', 'ترج', 'رجع', 'هات', 'اتو', 'تول', 'ولع', 'اكت', 'كتر', 'عشق', 'شقى', 'للص', 'لصو', 'صور', 'وره', 'ولعه', 'لعها', 'واخر', 'اخرب', 'خربه', 'ربها', 'يامي', 'امين', 'مينو', 'هاتو', 'اتول', 'تولع', 'للصو', 'لصور', 'صوره', 'ول', 'لع', 'عه', 'ها', 'وا', 'اخ', 'خر', 'رب', 'به', 'ها', 'يا', 'ام', 'مي', 'ين', 'نو', 'اخ', 'خر', 'يو', 'وم', 'ول', 'لم', 'ما', 'تر', 'رج', 'جع', 'ها', 'ات', 'تو', 'ول', 'لع', 'اك', 'كت', 'تر', 'عش', 'شق', 'قى', 'لل', 'لص', 'صو', 'ور', 'ره'], 'pos')
# (['حتي', 'الاهلي', 'خسر', 'مفيش', 'فايدة', 'الا', 'لاه', 'اهل', 'هلي', 'مفي', 'فيش', 'فاي', 'ايد', 'يدة', 'الاه', 'لاهل', 'اهلي', 'فايد', 'ايدة', 'حت', 'تي', 'ال', 'لا', 'اه', 'هل', 'لي', 'خس', 'سر', 'مف', 'في', 'يش', 'فا', 'اي', 'يد', 'دة'], 'neg')
# (['جاريدو', 'بيجرب', 'جار', 'اري', 'ريد', 'يدو', 'بيج', 'يجر', 'جرب', 'جاري', 'اريد', 'ريدو', 'بيجر', 'يجرب', 'جا', 'ار', 'ري', 'يد', 'دو', 'بي', 'يج', 'جر', 'رب'], 'neu')
# (['دا', 'مخه', 'اهبل', 'هه', 'اهب', 'هبل', 'مخ', 'خه', 'اه', 'هب', 'بل'], 'neg')
# (['التحيه', 'والتقدير', 'لمن', 'يصنعون', 'الحياة', 'الت', 'لتح', 'تحي', 'حيه', 'وال', 'الت', 'لتق', 'تقد', 'قدي', 'دير', 'يصن', 'صنع', 'نعو', 'عون', 'الح', 'لحي', 'حيا', 'ياة', 'التح', 'لتحي', 'تحيه', 'والت', 'التق', 'لتقد', 'تقدي', 'قدير', 'يصنع', 'صنعو', 'نعون', 'الحي', 'لحيا', 'حياة', 'ال', 'لت', 'تح', 'حي', 'يه', 'وا', 'ال', 'لت', 'تق', 'قد', 'دي', 'ير', 'لم', 'من', 'يص', 'صن', 'نع', 'عو', 'ون', 'ال', 'لح', 'حي', 'يا', 'اة'], 'pos')
# (['ان', 'تتخيل', 'الاحساس', 'اللي', 'بتكون', 'سمعت', 'اغنية', 'مشاعر', 'بتاع', 'شيرين', 'الوقت', 'ده', 'اووف', 'حاجه', 'فشيخه', 'تتخ', 'تخي', 'خيل', 'الا', 'لاح', 'احس', 'حسا', 'ساس', 'الل', 'للي', 'بتك', 'تكو', 'كون', 'سمع', 'معت', 'اغن', 'غني', 'نية', 'مشا', 'شاع', 'اعر', 'بتا', 'تاع', 'شير', 'يري', 'رين', 'الو', 'لوق', 'وقت', 'اوو', 'ووف', 'حاج', 'اجه', 'فشي', 'شيخ', 'يخه', 'تتخي', 'تخيل', 'الاح', 'لاحس', 'احسا', 'حساس', 'بتكو', 'تكون', 'اغني', 'غنية', 'مشاع', 'شاعر', 'شيري', 'يرين', 'الوق', 'لوقت', 'فشيخ', 'شيخه', 'تت', 'تخ', 'خي', 'يل', 'ال', 'لا', 'اح', 'حس', 'سا', 'اس', 'ال', 'لل', 'لي', 'بت', 'تك', 'كو', 'ون', 'سم', 'مع', 'عت', 'اغ', 'غن', 'ني', 'ية', 'مش', 'شا', 'اع', 'عر', 'بت', 'تا', 'اع', 'شي', 'ير', 'ري', 'ين', 'ال', 'لو', 'وق', 'قت', 'او', 'وو', 'وف', 'حا', 'اج', 'جه', 'فش', 'شي', 'يخ', 'خه'], 'pos')
# (['الأطفال', 'ليهم', 'الحق', 'فـ', 'رأيهم', 'السياسي', 'أصل', 'طفل', 'يبقى', 'صاحبه', 'معتقل', 'او', 'شهيد', 'اكيد', 'مش', 'هيسكت', 'الأ', 'لأط', 'أطف', 'طفا', 'فال', 'ليه', 'يهم', 'الح', 'لحق', 'رأي', 'أيه', 'يهم', 'الس', 'لسي', 'سيا', 'ياس', 'اسي', 'يبق', 'بقى', 'صاح', 'احب', 'حبه', 'معت', 'عتق', 'تقل', 'شهي', 'هيد', 'اكي', 'كيد', 'هيس', 'يسك', 'سكت', 'الأط', 'لأطف', 'أطفا', 'طفال', 'رأيه', 'أيهم', 'السي', 'لسيا', 'سياس', 'ياسي', 'صاحب', 'احبه', 'معتق', 'عتقل', 'هيسك', 'يسكت', 'ال', 'لأ', 'أط', 'طف', 'فا', 'ال', 'لي', 'يه', 'هم', 'ال', 'لح', 'حق', 'رأ', 'أي', 'يه', 'هم', 'ال', 'لس', 'سي', 'يا', 'اس', 'سي', 'أص', 'صل', 'طف', 'فل', 'يب', 'بق', 'قى', 'صا', 'اح', 'حب', 'به', 'مع', 'عت', 'تق', 'قل', 'شه', 'هي', 'يد', 'اك', 'كي', 'يد', 'هي', 'يس', 'سك', 'كت'], 'neu')
# (['انت', 'موجود', 'خيالي', 'اكتر', 'مانت', 'موجود', 'الواقع', 'موج', 'وجو', 'جود', 'خيا', 'يال', 'الي', 'اكت', 'كتر', 'مان', 'انت', 'موج', 'وجو', 'جود', 'الو', 'لوا', 'واق', 'اقع', 'موجو', 'وجود', 'خيال', 'يالي', 'موجو', 'وجود', 'الوا', 'لواق', 'واقع', 'ان', 'نت', 'مو', 'وج', 'جو', 'ود', 'خي', 'يا', 'ال', 'لي', 'اك', 'كت', 'تر', 'ما', 'ان', 'نت', 'مو', 'وج', 'جو', 'ود', 'ال', 'لو', 'وا', 'اق', 'قع'], 'neg')
# (['عملتيلو', 'عمل', 'ملت', 'لتي', 'تيل', 'يلو', 'عملت', 'ملتي', 'لتيل', 'تيلو', 'عم', 'مل', 'لت', 'تي', 'يل', 'لو'], 'neu')
# (['ديما', 'نقوللكم', 'ناس', 'كثر', 'الاكتئاب', 'لعندهم', 'يتمنوا', 'أنهم', 'أنخلقوا', 'حيوانات', 'حد', 'صدقني', 'ديم', 'يما', 'نقو', 'قول', 'ولل', 'للك', 'لكم', 'الا', 'لاك', 'اكت', 'كتئ', 'تئا', 'ئاب', 'لعن', 'عند', 'نده', 'دهم', 'يتم', 'تمن', 'منو', 'نوا', 'أنه', 'نهم', 'أنخ', 'نخل', 'خلق', 'لقو', 'قوا', 'حيو', 'يوا', 'وان', 'انا', 'نات', 'صدق', 'دقن', 'قني', 'نقول', 'قولل', 'وللك', 'للكم', 'الاك', 'لاكت', 'اكتئ', 'كتئا', 'تئاب', 'لعند', 'عنده', 'ندهم', 'يتمن', 'تمنو', 'منوا', 'أنخل', 'نخلق', 'خلقو', 'لقوا', 'حيوا', 'يوان', 'وانا', 'انات', 'صدقن', 'دقني', 'دي', 'يم', 'ما', 'نق', 'قو', 'ول', 'لل', 'لك', 'كم', 'نا', 'اس', 'كث', 'ثر', 'ال', 'لا', 'اك', 'كت', 'تئ', 'ئا', 'اب', 'لع', 'عن', 'ند', 'ده', 'هم', 'يت', 'تم', 'من', 'نو', 'وا', 'أن', 'نه', 'هم', 'أن', 'نخ', 'خل', 'لق', 'قو', 'وا', 'حي', 'يو', 'وا', 'ان', 'نا', 'ات', 'صد', 'دق', 'قن', 'ني'], 'neg')
# (['اللهم', 'الحمد', 'ينبغي', 'لج', 'وجهك', 'ولعظيم', 'سلطانك', 'الل', 'لله', 'لهم', 'الح', 'لحم', 'حمد', 'ينب', 'نبغ', 'بغي', 'وجه', 'جهك', 'ولع', 'لعظ', 'عظي', 'ظيم', 'سلط', 'لطا', 'طان', 'انك', 'الله', 'للهم', 'الحم', 'لحمد', 'ينبغ', 'نبغي', 'ولعظ', 'لعظي', 'عظيم', 'سلطا', 'لطان', 'طانك', 'ال', 'لل', 'له', 'هم', 'ال', 'لح', 'حم', 'مد', 'ين', 'نب', 'بغ', 'غي', 'وج', 'جه', 'هك', 'ول', 'لع', 'عظ', 'ظي', 'يم', 'سل', 'لط', 'طا', 'ان', 'نك'], 'pos')
# (['الأشياء', 'جمالها', 'نلحظها', 'وقت', 'متأخر', 'نشعر', 'قيد', 'الحب', 'قيد', 'الود', 'والحياة', 'نحدث', 'فارقا', 'مزكاكي', 'حصتي', 'الأ', 'لأش', 'أشي', 'شيا', 'ياء', 'جما', 'مال', 'اله', 'لها', 'نلح', 'لحظ', 'حظه', 'ظها', 'متأ', 'تأخ', 'أخر', 'نشع', 'شعر', 'الح', 'لحب', 'الو', 'لود', 'وال', 'الح', 'لحي', 'حيا', 'ياة', 'نحد', 'حدث', 'فار', 'ارق', 'رقا', 'مزك', 'زكا', 'كاك', 'اكي', 'حصت', 'صتي', 'الأش', 'لأشي', 'أشيا', 'شياء', 'جمال', 'ماله', 'الها', 'نلحظ', 'لحظه', 'حظها', 'متأخ', 'تأخر', 'والح', 'الحي', 'لحيا', 'حياة', 'فارق', 'ارقا', 'مزكا', 'زكاك', 'كاكي', 'ال', 'لأ', 'أش', 'شي', 'يا', 'اء', 'جم', 'ما', 'ال', 'له', 'ها', 'نل', 'لح', 'حظ', 'ظه', 'ها', 'وق', 'قت', 'مت', 'تأ', 'أخ', 'خر', 'نش', 'شع', 'عر', 'قي', 'يد', 'ال', 'لح', 'حب', 'قي', 'يد', 'ال', 'لو', 'ود', 'وا', 'ال', 'لح', 'حي', 'يا', 'اة', 'نح', 'حد', 'دث', 'فا', 'ار', 'رق', 'قا', 'مز', 'زك', 'كا', 'اك', 'كي', 'حص', 'صت', 'تي'], 'pos')
# (['يخليه', 'فحالة', 'يخل', 'خلي', 'ليه', 'فحا', 'حال', 'الة', 'يخلي', 'خليه', 'فحال', 'حالة', 'يخ', 'خل', 'لي', 'يه', 'فح', 'حا', 'ال', 'لة'], 'neg')
# (['عايزين', 'مينا', 'تويتر', 'كا', 'عاي', 'ايز', 'يزي', 'زين', 'مين', 'ينا', 'توي', 'ويت', 'يتر', 'عايز', 'ايزي', 'يزين', 'تويت', 'ويتر', 'عا', 'اي', 'يز', 'زي', 'ين', 'مي', 'ين', 'نا', 'تو', 'وي', 'يت', 'تر'], 'neu')
# (['محدش', 'حاسس', 'بحد', 'كله', 'بيقول', 'يلا', 'نفسى', 'محد', 'حدش', 'حاس', 'اسس', 'بيق', 'يقو', 'قول', 'نفس', 'فسى', 'بيقو', 'يقول', 'مح', 'حد', 'دش', 'حا', 'اس', 'سس', 'بح', 'حد', 'كل', 'له', 'بي', 'يق', 'قو', 'ول', 'يل', 'لا', 'نف', 'فس', 'سى'], 'neg')
# (['محدش', 'هيهتم', 'رجعت', 'البيت', 'دلقت', 'جاز', 'جسمك', 'الهالك', 'وولعت', 'مليت', 'الحوض', 'اخدت', 'منوم', 'وغرقت', 'محد', 'حدش', 'هيه', 'يهت', 'هتم', 'رجع', 'جعت', 'الب', 'لبي', 'بيت', 'دلق', 'لقت', 'جسم', 'سمك', 'اله', 'لها', 'هال', 'الك', 'وول', 'ولع', 'لعت', 'ملي', 'ليت', 'الح', 'لحو', 'حوض', 'اخد', 'خدت', 'منو', 'نوم', 'وغر', 'غرق', 'رقت', 'هيهت', 'يهتم', 'البي', 'لبيت', 'الها', 'لهال', 'هالك', 'وولع', 'ولعت', 'الحو', 'لحوض', 'وغرق', 'غرقت', 'مح', 'حد', 'دش', 'هي', 'يه', 'هت', 'تم', 'رج', 'جع', 'عت', 'ال', 'لب', 'بي', 'يت', 'دل', 'لق', 'قت', 'جا', 'از', 'جس', 'سم', 'مك', 'ال', 'له', 'ها', 'ال', 'لك', 'وو', 'ول', 'لع', 'عت', 'مل', 'لي', 'يت', 'ال', 'لح', 'حو', 'وض', 'اخ', 'خد', 'دت', 'من', 'نو', 'وم', 'وغ', 'غر', 'رق', 'قت'], 'neg')
# (['تسلم', 'تسل', 'سلم', 'تس', 'سل', 'لم'], 'pos')
# (['رمز', 'للفن', 'الراقي', 'ولديها', 'قبول', 'واحساس', 'وصوت', 'روعة', 'رنا', 'سماحة', 'إنت', 'حر', 'للف', 'لفن', 'الر', 'لرا', 'راق', 'اقي', 'ولد', 'لدي', 'ديه', 'يها', 'قبو', 'بول', 'واح', 'احس', 'حسا', 'ساس', 'وصو', 'صوت', 'روع', 'وعة', 'سما', 'ماح', 'احة', 'الرا', 'لراق', 'راقي', 'ولدي', 'لديه', 'ديها', 'واحس', 'احسا', 'حساس', 'سماح', 'ماحة', 'رم', 'مز', 'لل', 'لف', 'فن', 'ال', 'لر', 'را', 'اق', 'قي', 'ول', 'لد', 'دي', 'يه', 'ها', 'قب', 'بو', 'ول', 'وا', 'اح', 'حس', 'سا', 'اس', 'وص', 'صو', 'وت', 'رو', 'وع', 'عة', 'رن', 'نا', 'سم', 'ما', 'اح', 'حة', 'إن', 'نت'], 'pos')
# (['رنا', 'جودعان', 'مينا', 'فخر', 'العرب', 'جود', 'ودع', 'دعا', 'عان', 'مين', 'ينا', 'الع', 'لعر', 'عرب', 'جودع', 'ودعا', 'دعان', 'العر', 'لعرب', 'رن', 'نا', 'جو', 'ود', 'دع', 'عا', 'ان', 'مي', 'ين', 'نا', 'فخ', 'خر', 'ال', 'لع', 'عر', 'رب'], 'pos')
# (['حد', 'قالك', 'انك', 'واحدة', 'وسخة', 'بلووك', 'قال', 'الك', 'واح', 'احد', 'حدة', 'وسخ', 'سخة', 'بلو', 'لوو', 'ووك', 'واحد', 'احدة', 'بلوو', 'لووك', 'قا', 'ال', 'لك', 'ان', 'نك', 'وا', 'اح', 'حد', 'دة', 'وس', 'سخ', 'خة', 'بل', 'لو', 'وو', 'وك'], 'neg')
# (['ازاي', 'اسماء', 'ازا', 'زاي', 'اسم', 'سما', 'ماء', 'اسما', 'سماء', 'از', 'زا', 'اي', 'اس', 'سم', 'ما', 'اء'], 'neu')
# (['عبدالظاهر', 'هايل', 'الشوط', 'التاني', 'عبد', 'بدا', 'دال', 'الظ', 'لظا', 'ظاه', 'اهر', 'هاي', 'ايل', 'الش', 'لشو', 'شوط', 'الت', 'لتا', 'تان', 'اني', 'عبدا', 'بدال', 'دالظ', 'الظا', 'لظاه', 'ظاهر', 'الشو', 'لشوط', 'التا', 'لتان', 'تاني', 'عب', 'بد', 'دا', 'ال', 'لظ', 'ظا', 'اه', 'هر', 'ها', 'اي', 'يل', 'ال', 'لش', 'شو', 'وط', 'ال', 'لت', 'تا', 'ان', 'ني'], 'pos')
# (['عرفت', 'اللي', 'عنيه', 'بآن', 'عاليها', 'إنو', 'قلبي', 'حبنيش', 'حجات', 'عشنا', 'وعشمنا', 'بيها', 'وأخرتها', 'ايه', 'طلعت', 'مفيش', 'عرف', 'رفت', 'الل', 'للي', 'عني', 'نيه', 'عال', 'الي', 'ليه', 'يها', 'قلب', 'لبي', 'حبن', 'بني', 'نيش', 'حجا', 'جات', 'عشن', 'شنا', 'وعش', 'عشم', 'شمن', 'منا', 'بيه', 'يها', 'وأخ', 'أخر', 'خرت', 'رته', 'تها', 'طلع', 'لعت', 'مفي', 'فيش', 'عالي', 'اليه', 'ليها', 'حبني', 'بنيش', 'وعشم', 'عشمن', 'شمنا', 'وأخر', 'أخرت', 'خرته', 'رتها', 'عر', 'رف', 'فت', 'ال', 'لل', 'لي', 'عن', 'ني', 'يه', 'بآ', 'آن', 'عا', 'ال', 'لي', 'يه', 'ها', 'إن', 'نو', 'قل', 'لب', 'بي', 'حب', 'بن', 'ني', 'يش', 'حج', 'جا', 'ات', 'عش', 'شن', 'نا', 'وع', 'عش', 'شم', 'من', 'نا', 'بي', 'يه', 'ها', 'وأ', 'أخ', 'خر', 'رت', 'ته', 'ها', 'اي', 'يه', 'طل', 'لع', 'عت', 'مف', 'في', 'يش'], 'neg')
# (['كنت', 'عايز', 'اقوله', 'سعادتك', 'احنا', 'ساعة', 'خطينا', 'الكلية', 'واحنا', 'عارفين', 'كدة', 'يعني', 'ماضفتش', 'جديد', 'انت', 'متعرفش', 'بيعمل', 'ايه', 'عشان', 'يوصل', 'للمعلومة', 'عاي', 'ايز', 'اقو', 'قول', 'وله', 'سعا', 'عاد', 'ادت', 'دتك', 'احن', 'حنا', 'ساع', 'اعة', 'خطي', 'طين', 'ينا', 'الك', 'لكل', 'كلي', 'لية', 'واح', 'احن', 'حنا', 'عار', 'ارف', 'رفي', 'فين', 'يعن', 'عني', 'ماض', 'اضف', 'ضفت', 'فتش', 'جدي', 'ديد', 'متع', 'تعر', 'عرف', 'رفش', 'بيع', 'يعم', 'عمل', 'عشا', 'شان', 'يوص', 'وصل', 'للم', 'لمع', 'معل', 'علو', 'لوم', 'ومة', 'اقول', 'قوله', 'سعاد', 'عادت', 'ادتك', 'خطين', 'طينا', 'الكل', 'لكلي', 'كلية', 'واحن', 'احنا', 'عارف', 'ارفي', 'رفين', 'ماضف', 'اضفت', 'ضفتش', 'متعر', 'تعرف', 'عرفش', 'بيعم', 'يعمل', 'للمع', 'لمعل', 'معلو', 'علوم', 'لومة', 'كن', 'نت', 'عا', 'اي', 'يز', 'اق', 'قو', 'ول', 'له', 'سع', 'عا', 'اد', 'دت', 'تك', 'اح', 'حن', 'نا', 'سا', 'اع', 'عة', 'خط', 'طي', 'ين', 'نا', 'ال', 'لك', 'كل', 'لي', 'ية', 'وا', 'اح', 'حن', 'نا', 'عا', 'ار', 'رف', 'في', 'ين', 'كد', 'دة', 'يع', 'عن', 'ني', 'ما', 'اض', 'ضف', 'فت', 'تش', 'جد', 'دي', 'يد', 'ان', 'نت', 'مت', 'تع', 'عر', 'رف', 'فش', 'بي', 'يع', 'عم', 'مل', 'اي', 'يه', 'عش', 'شا', 'ان', 'يو', 'وص', 'صل', 'لل', 'لم', 'مع', 'عل', 'لو', 'وم', 'مة'], 'neu')
# (['الراعي', 'يترأس', 'الصلاة', 'لراحة', 'المطران', 'الدويهي', 'الظهر', 'الر', 'لرا', 'راع', 'اعي', 'يتر', 'ترأ', 'رأس', 'الص', 'لصل', 'صلا', 'لاة', 'لرا', 'راح', 'احة', 'الم', 'لمط', 'مطر', 'طرا', 'ران', 'الد', 'لدو', 'دوي', 'ويه', 'يهي', 'الظ', 'لظه', 'ظهر', 'الرا', 'لراع', 'راعي', 'يترأ', 'ترأس', 'الصل', 'لصلا', 'صلاة', 'لراح', 'راحة', 'المط', 'لمطر', 'مطرا', 'طران', 'الدو', 'لدوي', 'دويه', 'ويهي', 'الظه', 'لظهر', 'ال', 'لر', 'را', 'اع', 'عي', 'يت', 'تر', 'رأ', 'أس', 'ال', 'لص', 'صل', 'لا', 'اة', 'لر', 'را', 'اح', 'حة', 'ال', 'لم', 'مط', 'طر', 'را', 'ان', 'ال', 'لد', 'دو', 'وي', 'يه', 'هي', 'ال', 'لظ', 'ظه', 'هر'], 'neu')
# (['مرحبا', 'كيفك', 'احمد', 'رقم', 'الهاتف', 'الجوال', 'مرح', 'رحب', 'حبا', 'كيف', 'يفك', 'احم', 'حمد', 'اله', 'لها', 'هات', 'اتف', 'الج', 'لجو', 'جوا', 'وال', 'مرحب', 'رحبا', 'الها', 'لهات', 'هاتف', 'الجو', 'لجوا', 'جوال', 'مر', 'رح', 'حب', 'با', 'كي', 'يف', 'فك', 'اح', 'حم', 'مد', 'رق', 'قم', 'ال', 'له', 'ها', 'ات', 'تف', 'ال', 'لج', 'جو', 'وا', 'ال'], 'pos')
# (['الفكره', 'اللي', 'ماخذينها', 'عني', 'رجعوها', 'والمره', 'اليايه', 'تاخذون', 'شي', 'مو', 'عيب', 'هالحركات', 'الف', 'لفك', 'فكر', 'كره', 'الل', 'للي', 'ماخ', 'اخذ', 'خذي', 'ذين', 'ينه', 'نها', 'رجع', 'جعو', 'عوه', 'وها', 'وال', 'الم', 'لمر', 'مره', 'الي', 'ليا', 'ياي', 'ايه', 'تاخ', 'اخذ', 'خذو', 'ذون', 'هال', 'الح', 'لحر', 'حرك', 'ركا', 'كات', 'الفك', 'لفكر', 'فكره', 'ماخذ', 'اخذي', 'خذين', 'ذينه', 'ينها', 'رجعو', 'جعوه', 'عوها', 'والم', 'المر', 'لمره', 'اليا', 'لياي', 'يايه', 'تاخذ', 'اخذو', 'خذون', 'هالح', 'الحر', 'لحرك', 'حركا', 'ركات', 'ال', 'لف', 'فك', 'كر', 'ره', 'ال', 'لل', 'لي', 'ما', 'اخ', 'خذ', 'ذي', 'ين', 'نه', 'ها', 'عن', 'ني', 'رج', 'جع', 'عو', 'وه', 'ها', 'وا', 'ال', 'لم', 'مر', 'ره', 'ال', 'لي', 'يا', 'اي', 'يه', 'تا', 'اخ', 'خذ', 'ذو', 'ون', 'عي', 'يب', 'ها', 'ال', 'لح', 'حر', 'رك', 'كا', 'ات'], 'neg')
# (['لاعب', 'لعب', 'الماتشات', 'ال', 'اللاعبين', 'كلهم', 'تغيبوا', 'فى', 'الماتشات', 'لاع', 'اعب', 'الم', 'لما', 'مات', 'اتش', 'تشا', 'شات', 'الل', 'للا', 'لاع', 'اعب', 'عبي', 'بين', 'كله', 'لهم', 'تغي', 'غيب', 'يبو', 'بوا', 'الم', 'لما', 'مات', 'اتش', 'تشا', 'شات', 'الما', 'لمات', 'ماتش', 'اتشا', 'تشات', 'اللا', 'للاع', 'لاعب', 'اعبي', 'عبين', 'تغيب', 'غيبو', 'يبوا', 'الما', 'لمات', 'ماتش', 'اتشا', 'تشات', 'لا', 'اع', 'عب', 'لع', 'عب', 'ال', 'لم', 'ما', 'ات', 'تش', 'شا', 'ات', 'ال', 'لل', 'لا', 'اع', 'عب', 'بي', 'ين', 'كل', 'له', 'هم', 'تغ', 'غي', 'يب', 'بو', 'وا', 'ال', 'لم', 'ما', 'ات', 'تش', 'شا', 'ات'], 'neu')

# %% [markdown]
# # Test data info

# %%
# print('test data info')
# test_data = 
# print('test data size', len(train_data))
# print('# of positive', len(pos_test_data))
# print('# of negative', len(neg_test_data))

# %% [markdown]
# # merging all features ...

# %%
print('merging all features ... ')
all_features = train_feat + test_feat
print('len(all_features):', len(all_features))
# Out:
# merging all features ...
# len(all_features): 195204

# %% [markdown]
# # Sample features

# %%
print('{} sample features ...'.format(sample_size))
print(random.sample(all_features, sample_size))
# Out:
# 100 sample features ...
# ['بصر', 'مس', 'بيد', 'لمفأ', 'ود', 'يبتى', 'سف', 'نفس', 'يين', 'وا', 'فسترتني', 'لا', 'لمز', 'هم', 'ني', 'انب', 'عامله', 'ادس', 'قبر', 'ال', 'للي', 'لبسا', 'يس', 'اص', 'فش', 'منى', 'باس', 'لت', 'اموا', 'يـه', 'اختب', 'ال', 'اع', 'حق', 'تلا', 'هيف', 'بتي', 'لوم', 'ال', 'هل', 'بض', 'احلى', 'لاخر', 'لشوق', 'عاف', 'وت', 'بن', 'كفتة', 'وهم', 'عا', 'الب', 'ان', 'مك', 'عتنا', 'وا', 'ضاال', 'لى', 'تعات', 'اك', 'قه', 'هالحلم', 'مريك', 'وال', 'عندها', 'اعم', 'الع', 'يز', 'ادا', 'لر', 'ان', 'دسس', 'وي', 'منز', 'لام', 'الت', 'لم', 'لان', 'بل', 'نا', 'البيت', 'لح', 'عرف', 'ال', 'ده', 'الش', 'حد', 'المن', 'تكون', 'سماس', 'قر', 'لن', 'شا', 'الله', 'فا', 'يت', 'ال', 'قـا', 'ومكم', 'له', 'ست']

# %% [markdown]
# # compute frequencies

# %%
all_features_count = {}
for w in all_features:
    all_features_count[w] = all_features_count.get(w, 0) + 1

# %%
all_features_count
# Out:
# {'الفاشل': 1,
#  'تخرج': 2,
#  'بنظام': 1,
#  'التحسين': 1,
#  'اختراعك': 1,
#  'الف': 165,
#  'لفا': 15,
#  'فاش': 7,
#  'اشل': 6,
#  'تخر': 4,
#  'خرج': 7,
#  'بنظ': 1,
#  'نظا': 7,
#  'ظام': 6,
#  'الت': 195,
#  'لتح': 12,
#  'تحس': 8,
#  'حسي': 7,
#  'سين': 24,
#  'اخت': 21,
#  'ختر': 3,
#  'ترا': 30,
#  'راع': 8,
#  'اعك': 6,
#  'الفا': 14,
#  'لفاش': 2,
#  'فاشل': 6,
#  'بنظا': 1,
#  'نظام': 5,
#  'التح': 9,
#  'لتحس': 1,
#  'تحسي': 2,
#  'حسين': 5,
#  'اختر': 3,
#  'خترا': 3,
#  'تراع': 2,
#  'راعك': 2,
#  'ال': 5185,
#  'لف': 207,
#  'فا': 255,
#  'اش': 146,
#  'شل': 26,
#  'تخ': 70,
#  'خر': 104,
#  'رج': 109,
#  'بن': 310,
#  'نظ': 31,
#  'ظا': 32,
#  'ام': 682,
#  'لت': 320,
#  'تح': 269,
#  'حس': 136,
#  'سي': 293,
#  'ين': 913,
#  'اخ': 163,
#  'خت': 41,
#  'تر': 255,
#  'را': 458,
#  'اع': 315,
#  'عك': 26,
#  'الحق': 28,
#  'يتقال': 1,
#  'مسلسل': 5,
#  'فشيخ': 2,
#  'بصراحة': 2,
#  'الح': 275,
#  'لحق': 29,
#  'يتق': 5,
#  'تقا': 17,
#  'قال': 61,
#  'مسل': 20,
#  'سلس': 8,
#  'لسل': 41,
#  'فشي': 2,
#  'شيخ': 11,
#  'بصر': 7,
#  'صرا': 18,
#  'راح': 26,
#  'احة': 41,
#  'يتقا': 1,
#  'تقال': 5,
#  'مسلس': 7,
#  'سلسل': 8,
#  'بصرا': 5,
#  'صراح': 11,
#  'راحة': 5,
#  'لح': 339,
#  'حق': 95,
#  'يت': 294,
#  'تق': 150,
#  'قا': 227,
#  'مس': 165,
#  'سل': 176,
#  'لس': 316,
#  'فش': 42,
#  'شي': 156,
#  'يخ': 71,
#  'بص': 30,
#  'صر': 195,
#  'اح': 444,
#  'حة': 79,
#  'ـي': 28,
#  'أأر': 1,
#  'ــق': 1,
#  'ــي': 16,
#  'قصائد': 1,
#  'ــه': 9,
#  'ـن': 21,
#  'أأجل': 1,
#  'قصا': 6,
#  'صائ': 2,
#  'ائد': 7,
#  'أأج': 1,
#  'أجل': 6,
#  'قصائ': 1,
#  'صائد': 1,
#  'أأ': 2,
#  'أر': 31,
#  'ــ': 124,
#  'ـق': 4,
#  'قص': 62,
#  'صا': 115,
#  'ائ': 143,
#  'ئد': 8,
#  'ـه': 15,
#  'أج': 32,
#  'جل': 63,
#  'مش': 308,
#  'هتاخد': 2,
#  'تلت': 4,
#  'ساعة': 9,
#  'هتا': 5,
#  'تاخ': 12,
#  'اخد': 28,
#  'ساع': 37,
#  'اعة': 25,
#  'هتاخ': 2,
#  'تاخد': 9,
#  'هت': 71,
#  'تا': 314,
#  'خد': 64,
#  'تل': 96,
#  'سا': 336,
#  'عة': 77,
#  'تكريم': 1,
#  'أستاذنا': 1,
#  'رافت': 1,
#  'نجيب': 4,
#  'تكر': 19,
#  'كري': 48,
#  'ريم': 20,
#  'أست': 10,
#  'ستا': 33,
#  'تاذ': 11,
#  'اذن': 4,
#  'ذنا': 1,
#  'راف': 12,
#  'افت': 22,
#  'نجي': 9,
#  'جيب': 21,
#  'تكري': 1,
#  'كريم': 13,
#  'أستا': 5,
#  'ستاذ': 11,
#  'تاذن': 1,
#  'اذنا': 1,
#  'تك': 265,
#  'كر': 281,
#  'ري': 526,
#  'يم': 197,
#  'أس': 83,
#  'ست': 236,
#  'اذ': 53,
#  'ذن': 24,
#  'نا': 1324,
#  'اف': 189,
#  'فت': 140,
#  'نج': 74,
#  'جي': 127,
#  'يب': 308,
#  'نفسي': 35,
#  'مرة': 15,
#  'أجرب': 1,
#  'أكون': 2,
#  'ليك': 55,
#  'حد': 255,
#  'أقرب': 1,
#  'نفس': 113,
#  'فسي': 39,
#  'أجر': 8,
#  'جرب': 9,
#  'أكو': 2,
#  'كون': 84,
#  'أقر': 1,
#  'قرب': 15,
#  'نف': 176,
#  'فس': 134,
#  'مر': 238,
#  'رة': 178,
#  'جر': 94,
#  'رب': 390,
#  'أك': 26,
#  'كو': 180,
#  'ون': 366,
#  'لي': 958,
#  'يك': 238,
#  'أق': 17,
#  'قر': 113,
#  'روعة': 2,
#  'روع': 13,
#  'وعة': 6,
#  'رو': 262,
#  'وع': 144,
#  'بيكفي': 1,
#  'تلعب': 5,
#  'بأعصابي': 1,
#  'بيك': 22,
#  'يكف': 5,
#  'كفي': 12,
#  'تلع': 6,
#  'لعب': 35,
#  'بأع': 2,
#  'أعص': 1,
#  'عصا': 4,
#  'صاب': 17,
#  'ابي': 39,
#  'بيكف': 1,
#  'يكفي': 5,
#  'بأعص': 1,
#  'أعصا': 1,
#  'عصاب': 3,
#  'صابي': 1,
#  'بي': 599,
#  'كف': 45,
#  'في': 282,
#  'لع': 336,
#  'عب': 163,
#  'بأ': 26,
#  'أع': 24,
#  'عص': 24,
#  'اب': 454,
#  'اجى': 3,
#  'اركب': 1,
#  'عليكى': 5,
#  'ورا': 29,
#  'احطه': 2,
#  'جواكى': 1,
#  'شرموطه': 2,
#  'ارك': 29,
#  'ركب': 4,
#  'علي': 185,
#  'يكى': 10,
#  'احط': 2,
#  'حطه': 2,
#  'جوا': 24,
#  'واك': 11,
#  'اكى': 3,
#  'شرم': 4,
#  'رمو': 7,
#  'موط': 4,
#  'وطه': 4,
#  'عليك': 25,
#  'ليكى': 7,
#  'جواك': 2,
#  'واكى': 1,
#  'شرمو': 2,
#  'رموط': 2,
#  'موطه': 2,
#  'اج': 280,
#  'جى': 9,
#  'ار': 653,
#  'رك': 123,
#  'كب': 59,
#  'عل': 383,
#  'كى': 24,
#  'ور': 333,
#  'حط': 20,
#  'طه': 25,
#  'جو': 136,
#  'وا': 1101,
#  'اك': 249,
#  'شر': 127,
#  'رم': 82,
#  'مو': 247,
#  'وط': 67,
#  'تلج': 7,
#  'السنين': 2,
#  'الس': 236,
#  'لسن': 22,
#  'سني': 18,
#  'نين': 62,
#  'السن': 20,
#  'لسني': 3,
#  'سنين': 15,
#  'لج': 166,
#  'سن': 177,
#  'ني': 574,
#  'صباحكما': 1,
#  'سعد': 32,
#  'صبا': 18,
#  'باح': 22,
#  'احك': 14,
#  'حكم': 37,
#  'كما': 33,
#  'صباح': 17,
#  'باحك': 9,
#  'احكم': 3,
#  'حكما': 2,
#  'صب': 85,
#  'با': 567,
#  'حك': 123,
#  'كم': 195,
#  'ما': 613,
#  'سع': 112,
#  'عد': 176,
#  'كفايا': 2,
#  'جماعة': 7,
#  'أنتو': 1,
#  'بتصدقوا': 1,
#  'احاا': 3,
#  'كده': 48,
#  'والله': 52,
#  'كسم': 9,
#  'الاهلي': 15,
#  'الاتحاد': 7,
#  'الدوري': 6,
#  'المصري': 19,
#  'مصر': 131,
#  'الرياضة': 1,
#  'بشكل': 2,
#  'عام': 88,
#  'كفا': 17,
#  'فاي': 23,
#  'ايا': 53,
#  'جما': 36,
#  'ماع': 33,
#  'أنت': 10,
#  'نتو': 18,
#  'بتص': 4,
#  'تصد': 8,
#  'صدق': 26,
#  'دقو': 2,
#  'قوا': 19,
#  'احا': 13,
#  'حاا': 6,
#  'وال': 301,
#  'الل': 618,
#  'لله': 404,
#  'الا': 396,
#  'لاه': 42,
#  'اهل': 57,
#  'هلي': 29,
#  'لات': 68,
#  'اتح': 28,
#  'تحا': 63,
#  'حاد': 26,
#  'الد': 127,
#  'لدو': 27,
#  'دور': 26,
#  'وري': 33,
#  'الم': 488,
#  'لمص': 77,
#  'صري': 56,
#  'الر': 98,
#  'لري': 10,
#  'ريا': 37,
#  'ياض': 15,
#  'اضة': 2,
#  'بشك': 2,
#  'شكل': 31,
#  'كفاي': 15,
#  'فايا': 2,
#  'جماع': 14,
#  'ماعة': 8,
#  'بتصد': 1,
#  'تصدق': 3,
#  'صدقو': 1,
#  'دقوا': 1,
#  'والل': 67,
#  'الله': 357,
#  'الاه': 32,
#  'لاهل': 28,
#  'اهلي': 19,
#  'الات': 24,
#  'لاتح': 15,
#  'اتحا': 17,
#  'تحاد': 20,
#  'الدو': 24,
#  'لدور': 12,
#  'دوري': 11,
#  'المص': 69,
#  'لمصر': 52,
#  'مصري': 51,
#  'الري': 9,
#  'لريا': 8,
#  'رياض': 13,
#  'ياضة': 1,
#  'اي': 518,
#  'يا': 744,
#  'جم': 157,
#  'أن': 83,
#  'نت': 487,
#  'تو': 242,
#  'بت': 332,
#  'تص': 77,
#  'صد': 83,
#  'دق': 50,
#  'قو': 213,
#  'حا': 373,
#  'اا': 158,
#  'كد': 99,
#  'ده': 283,
#  'لل': 814,
#  'له': 748,
#  'كس': 59,
#  'سم': 193,
#  'لا': 1042,
#  'اه': 375,
#  'هل': 109,
#  'ات': 644,
#  'اد': 355,
#  'لد': 199,
#  'دو': 167,
#  'لم': 805,
#  'مص': 188,
#  'لر': 109,
#  'اض': 68,
#  'ضة': 4,
#  'بش': 49,
#  'شك': 80,
#  'كل': 337,
#  'عا': 554,
#  'زمان': 17,
#  'عاش': 8,
#  'شافك': 1,
#  'زما': 52,
#  'مان': 88,
#  'شاف': 7,
#  'افك': 4,
#  'زم': 112,
#  'ان': 1595,
#  'شا': 274,
#  'فك': 61,
#  'كلمه': 11,
#  'واحده': 10,
#  'يوم': 97,
#  'تصرف': 5,
#  'صدفه': 1,
#  'ممكن': 41,
#  'تغيرك': 1,
#  'كتير': 23,
#  'كلم': 68,
#  'لمه': 24,
#  'واح': 70,
#  'احد': 53,
#  'حده': 23,
#  'تصر': 12,
#  'صرف': 7,
#  'صدف': 5,
#  'دفه': 1,
#  'ممك': 42,
#  'مكن': 60,
#  'تغي': 7,
#  'غير': 55,
#  'يرك': 19,
#  'كتي': 28,
#  'تير': 25,
#  'واحد': 41,
#  'احده': 13,
#  'تغير': 6,
#  'غيرك': 11,
#  'مه': 149,
#  'يو': 253,
#  'وم': 286,
#  'رف': 198,
#  'دف': 27,
#  'فه': 92,
#  'مم': 65,
#  'مك': 185,
#  'كن': 168,
#  'تغ': 46,
#  'غي': 75,
#  'ير': 461,
#  'كت': 174,
#  'تي': 271,
#  'جوول': 3,
#  'جوو': 5,
#  'وول': 9,
#  'وو': 98,
#  'ول': 536,
#  'اهنا': 1,
#  'دايما': 12,
#  'محتاجين': 4,
#  'ربنا': 86,
#  'وقت': 48,
#  'زنقه': 1,
#  'اهن': 3,
#  'هنا': 7,
#  'داي': 33,
#  'ايم': 32,
#  'يما': 30,
#  'محت': 25,
#  'حتا': 25,
#  'تاج': 33,
#  'اجي': 11,
#  'جين': 16,
#  'ربن': 86,
#  'بنا': 146,
#  'زنق': 2,
#  'نقه': 1,
#  'دايم': 13,
#  'ايما': 15,
#  'محتا': 15,
#  'حتاج': 23,
#  'تاجي': 5,
#  'اجين': 6,
#  'هن': 53,
#  'دا': 346,
#  'مح': 197,
#  'حت': 148,
#  'وق': 160,
#  'قت': 131,
#  'زن': 30,
#  'نق': 48,
#  'قه': 65,
#  'أمريكا': 2,
#  'داخله': 2,
#  'مجلس': 5,
#  'الأمن': 2,
#  'عشان': 81,
#  'تعمل': 19,
#  'الفيتو': 1,
#  'أمر': 16,
#  'مري': 17,
#  'ريك': 6,
#  'يكا': 11,
#  'داخ': 15,
#  'اخل': 21,
#  'خله': 3,
#  'مجل': 8,
#  'جلس': 9,
#  'الأ': 122,
#  'لأم': 14,
#  'أمن': 5,
#  'عشا': 83,
#  'شان': 102,
#  'تعم': 22,
#  'عمل': 87,
#  'لفي': 36,
#  'فيت': 5,
#  'يتو': 13,
#  'أمري': 5,
#  'مريك': 4,
#  'ريكا': 5,
#  'داخل': 15,
#  'اخله': 2,
#  'الأم': 14,
#  'لأمن': 2,
#  'الفي': 28,
#  'لفيت': 1,
#  'فيتو': 1,
#  'أم': 66,
#  'كا': 209,
#  'خل': 178,
#  'مج': 54,
#  'لأ': 165,
#  'من': 330,
#  'عش': 136,
#  'تع': 205,
#  'عم': 219,
#  'مل': 317,
#  'يحتاج': 2,
#  'اكثر': 7,
#  'فريق': 14,
#  'فايز': 1,
#  'بالدوري': 1,
#  'الابطال': 1,
#  'يحت': 22,
#  'اكث': 7,
#  'كثر': 13,
#  'فري': 20,
#  'ريق': 37,
#  'ايز': 40,
#  'بال': 207,
#  'لاب': 34,
#  'ابط': 11,
#  'بطا': 14,
#  'طال': 20,
#  'يحتا': 3,
#  'بالد': 8,
#  'الاب': 5,
#  'لابط': 1,
#  'ابطا': 1,
#  'بطال': 4,
#  'يح': 165,
#  'كث': 19,
#  'ثر': 23,
#  'فر': 216,
#  'يق': 202,
#  'يز': 102,
#  'بط': 71,
#  'طا': 105,
#  'محاسب': 1,
#  'يحاول': 1,
#  'الانتحار': 2,
#  'بإلقاء': 1,
#  'نفسه': 32,
#  'المترو': 1,
#  'لعجز': 2,
#  'مليون': 9,
#  'بعهدته': 1,
#  'محا': 17,
#  'حاس': 22,
#  'اسب': 21,
#  'يحا': 8,
#  'حاو': 25,
#  'اول': 75,
#  'لان': 99,
#  'انت': 253,
#  'نتح': 5,
#  'حار': 7,
#  'بإل': 1,
#  'إلق': 1,
#  'لقا': 32,
#  'قاء': 14,
#  'فسه': 32,
#  'لمت': 35,
#  'متر': 5,
#  'ترو': 17,
#  'لعج': 6,
#  'عجز': 7,
#  'ملي': 47,
#  'ليو': 46,
#  'يون': 40,
#  'بعه': 11,
#  'عهد': 4,
#  'هدت': 2,
#  'دته': 14,
#  'محاس': 4,
#  'حاسب': 6,
#  'يحاو': 3,
#  'حاول': 23,
#  'الان': 44,
#  'لانت': 10,
#  'انتح': 2,
#  'نتحا': 2,
#  'تحار': 2,
#  'بإلق': 1,
#  'إلقا': 1,
#  'لقاء': 9,
#  'المت': 23,
#  'لمتر': 1,
#  'مترو': 4,
#  'مليو': 11,
#  'ليون': 12,
#  'بعهد': 1,
#  'عهدت': 1,
#  'هدته': 2,
#  'اس': 461,
#  'سب': 131,
#  'او': 243,
#  'بإ': 6,
#  'إل': 27,
#  'لق': 234,
#  'اء': 215,
#  'سه': 110,
#  'مت': 239,
#  'عج': 33,
#  'جز': 40,
#  'بع': 132,
#  'عه': 92,
#  'هد': 80,
#  'دت': 42,
#  'ته': 244,
#  'حيااتى': 1,
#  'دعااء': 1,
#  'انا': 295,
#  'بحببك': 1,
#  'اووى': 10,
#  'حبيبتى': 6,
#  'مستنياكى': 1,
#  'ناار': 2,
#  'حيا': 109,
#  'ياا': 29,
#  'اات': 4,
#  'اتى': 14,
#  'دعا': 43,
#  'عاا': 10,
#  'ااء': 3,
#  'بحب': 34,
#  'حبب': 4,
#  'ببك': 1,
#  'اوو': 17,
#  'ووى': 10,
#  'حبي': 56,
#  'بيب': 55,
#  'يبت': 20,
#  'بتى': 7,
#  'مست': 42,
#  'ستن': 16,
#  'تني': 39,
#  'نيا': 58,
#  'ياك': 10,
#  'ناا': 20,
#  'اار': 18,
#  'حياا': 3,
#  'ياات': 2,
#  'ااتى': 1,
#  'دعاا': 1,
#  'عااء': 1,
#  'بحبب': 1,
#  'حببك': 1,
#  'حبيب': 40,
#  'بيبت': 15,
#  'يبتى': 6,
#  'مستن': 10,
#  'ستني': 9,
#  'تنيا': 3,
#  'نياك': 2,
#  'ياكى': 1,
#  'حي': 235,
#  'تى': 86,
#  'دع': 104,
#  'بح': 140,
#  'حب': 297,
#  'بب': 31,
#  'بك': 164,
#  'وى': 50,
#  'تن': 181,
#  'فعلا': 18,
#  'صح': 78,
#  'عندك': 14,
#  'يرحمك': 2,
#  'امى': 6,
#  'فعل': 25,
#  'علا': 52,
#  'عند': 74,
#  'ندك': 14,
#  'يرح': 8,
#  'رحم': 40,
#  'حمك': 4,
#  'يرحم': 7,
#  'رحمك': 3,
#  'فع': 67,
#  'عن': 224,
#  'ند': 153,
#  'دك': 75,
#  'رح': 161,
#  'حم': 220,
#  'مى': 39,
#  'التمركز': 1,
#  'بتاع': 32,
#  'خط': 30,
#  'الضهر': 2,
#  'كله': 75,
#  'بليلة': 1,
#  'متقوليش': 1,
#  'هاني': 1,
#  'هايجبها': 1,
#  'ومتنساش': 1,
#  'واقف': 11,
#  'جون': 5,
#  'يعني': 34,
#  'لتم': 10,
#  'تمر': 12,
#  'مرك': 7,
#  'ركز': 5,
#  'بتا': 34,
#  'تاع': 34,
#  'الض': 23,
#  'لضه': 2,
#  'ضهر': 5,
#  'بلي': 28,
#  'ليل': 50,
#  'يلة': 35,
#  'متق': 5,
#  'تقو': 30,
#  'قول': 131,
#  'ولي': 41,
#  'ليش': 14,
#  'هان': 13,
#  'اني': 122,
#  'هاي': 18,
#  'ايج': 5,
#  'يجب': 9,
#  'جبه': 4,
#  'بها': 28,
#  'ومت': 2,
#  'متن': 14,
#  'تنس': 13,
#  'نسا': 40,
#  'ساش': 2,
#  'واق': 28,
#  'اقف': 14,
#  'يعن': 57,
#  'عني': 59,
#  'التم': 7,
#  'لتمر': 3,
#  'تمرك': 1,
#  'مركز': 3,
#  'الضه': 2,
#  'لضهر': 2,
#  'بليل': 5,
#  'ليلة': 11,
#  'متقو': 1,
#  'تقول': 24,
#  'قولي': 9,
#  'وليش': 1,
#  'هايج': 1,
#  'ايجب': 1,
#  'يجبه': 1,
#  'جبها': 1,
#  'ومتن': 1,
#  'متنس': 1,
#  'تنسا': 3,
#  'نساش': 2,
#  'تم': 161,
#  'كز': 6,
#  'لض': 25,
#  'ضه': 19,
#  'هر': 104,
#  'بل': 173,
#  'يل': 336,
#  'لة': 151,
#  'يش': 179,
#  'ها': 597,
#  'يج': 81,
#  'جب': 48,
#  'به': 143,
#  'نس': 167,
#  'اق': 212,
#  'قف': 41,
#  'يع': 200,
#  'سنه': 35,
#  'انتى': 26,
#  'طيوبه': 1,
#  'نتى': 32,
#  'طيو': 1,
#  'يوب': 5,
#  'وبه': 6,
#  'طيوب': 1,
#  'يوبه': 2,
#  'نه': 285,
#  'طي': 110,
#  'وب': 192,
#  'اذا': 26,
#  'بسمعه': 1,
#  'الوقتي': 1,
#  'السوند': 1,
#  'بسم': 11,
#  'سمع': 25,
#  'معه': 11,
#  'الو': 142,
#  'لوق': 37,
#  'قتي': 17,
#  'لسو': 11,
#  'سون': 7,
#  'وند': 1,
#  'بسمع': 4,
#  'سمعه': 3,
#  'الوق': 15,
#  'لوقت': 32,
#  'وقتي': 14,
#  'السو': 11,
#  'لسون': 2,
#  'سوند': 1,
#  'ذا': 89,
#  'بس': 82,
#  'مع': 263,
#  'لو': 453,
#  'سو': 114,
#  'يارب': 66,
#  'الكليه': 3,
#  'تولع': 3,
#  'الصبح': 10,
#  'الأمتحان': 1,
#  'يار': 104,
#  'ارب': 95,
#  'الك': 204,
#  'لكل': 72,
#  'كلي': 19,
#  'ليه': 115,
#  'تول': 6,
#  'ولع': 9,
#  'الص': 135,
#  'لصب': 21,
#  'صبح': 39,
#  'أمت': 3,
#  'متح': 44,
#  'حان': 44,
#  'الكل': 56,
#  'لكلي': 8,
#  'كليه': 5,
#  'الصب': 20,
#  'لصبح': 11,
#  'لأمت': 1,
#  'أمتح': 2,
#  'متحا': 34,
#  'تحان': 34,
#  'لك': 340,
#  'يه': 439,
#  'لص': 167,
#  'كتر': 34,
#  'الانشغال': 1,
#  'حاسس': 5,
#  'اجازتي': 2,
#  'كائن': 4,
#  'غريب': 9,
#  'بيتي': 1,
#  'بتعرف': 1,
#  'الاسرة': 1,
#  'وجديد': 1,
#  'انش': 9,
#  'نشغ': 2,
#  'شغا': 7,
#  'غال': 19,
#  'اسس': 5,
#  'اجا': 20,
#  'جاز': 11,
#  'ازت': 3,
#  'زتي': 3,
#  'كائ': 5,
#  'ائن': 8,
#  'غري': 14,
#  'ريب': 48,
#  'بيت': 44,
#  'يتي': 11,
#  'بتع': 10,
#  'تعر': 26,
#  'عرف': 79,
#  'لاس': 40,
#  'اسر': 12,
#  'سرة': 4,
#  'وجد': 7,
#  'جدي': 43,
#  'ديد': 49,
#  'لانش': 1,
#  'انشغ': 2,
#  'نشغا': 2,
#  'شغال': 6,
#  'اجاز': 5,
#  'جازت': 2,
#  'ازتي': 3,
#  'بتعر': 1,
#  'تعرف': 24,
#  'الاس': 31,
#  'لاسر': 2,
#  'اسرة': 1,
#  'وجدي': 2,
#  'جديد': 40,
#  'نش': 59,
#  'شغ': 30,
#  'غا': 66,
#  'سس': 11,
#  'جا': 151,
#  'از': 96,
#  'زت': 6,
#  'ئن': 17,
#  'غر': 59,
#  'عر': 172,
#  'سر': 108,
#  'وج': 110,
#  'جد': 127,
#  'دي': 416,
#  'يد': 316,
#  'الفكره': 1,
#  'اللي': 134,
#  'ماخذينها': 1,
#  'رجعوها': 1,
#  'والمره': 1,
#  'اليايه': 1,
#  'تاخذون': 1,
#  'عيب': 14,
#  'هالحركات': 1,
#  'لفك': 7,
#  'فكر': 30,
#  'كره': 56,
#  'للي': 141,
#  'ماخ': 2,
#  'اخذ': 6,
#  'خذي': 2,
#  'ذين': 3,
#  'ينه': 23,
#  'نها': 92,
#  'رجع': 30,
#  'جعو': 6,
#  'عوه': 4,
#  'وها': 15,
#  'لمر': 37,
#  'مره': 27,
#  'الي': 160,
#  'ليا': 48,
#  'ياي': 2,
#  'ايه': 89,
#  'خذو': 1,
#  'ذون': 1,
#  'هال': 16,
#  'لحر': 19,
#  'حرك': 5,
#  'ركا': 9,
#  ...}

# %% [markdown]
# # Sample Frequency

# %%
print('sample frequencies')
print(random.sample(list(all_features_count.items()), 30))
word = 'في'
print('freq of word {} is {}'.format(word, all_features_count.get(word, 0)))
word = 'فى'
print('freq of word {} is {}'.format(word, all_features_count.get(word, 0)))
word = 'من'
print('freq of word {} is {}'.format(word, all_features_count.get(word, 0)))
# Out:
# sample frequencies
# [('فيل', 14), ('إك', 2), ('انكم', 3), ('ودان', 2), ('صري', 56), ('ملاء', 2), ('ضفدع', 1), ('فرنس', 2), ('القهوه', 2), ('سانجيرمان', 1), ('اءه', 1), ('يوع', 1), ('كي', 128), ('أخبا', 7), ('والجنون', 1), ('تستغرب', 1), ('بأو', 1), ('تمشي', 1), ('اقصا', 1), ('راسو', 1), ('فودا', 2), ('بفستان', 1), ('وباكله', 1), ('مغير', 1), ('واغفرلي', 1), ('تفجر', 1), ('طبعاا', 1), ('غند', 2), ('وليش', 1), ('ويول', 1)]
# freq of word في is 282
# freq of word فى is 162
# freq of word من is 330

# %% [markdown]
# # Compute Threshold

# %%
print('size of training data:',  len(train_data))
min_df = int(0.001 * len(train_data))
max_df = int(0.98 * len(train_data))
print('min document frequency:', min_df)
print('max document frequency:', max_df)
# Out:
# size of training data: 2189
# min document frequency: 2
# max document frequency: 2145

# %% [markdown]
# # Selecting Features

# %%
# remove features that have frequency below/above the threshold
my_features = set([word for word, freq in all_features_count.items() if  max_df > freq > min_df ])
print(len(my_features), 'are kept out of', len(all_features))
# Out:
# 8921 are kept out of 195204

# %%
# re.sub("[a-zA-Z]+", "","abv-")

# %% [markdown]
# # Sample of selected features

# %%
print('{} sample of selected features:'.format(sample_size))
print(random.sample(list(my_features), sample_size))
# Out:
# 100 sample of selected features:
# ['عيل', 'قتصا', 'ليوم', 'ترين', 'الأه', 'حو', 'موج', 'قرض', 'ريش', 'لفصل', 'رقص', 'لظا', 'عنو', 'الرسول', 'لين', 'بصوت', 'يسمع', 'مصدر', 'جبل', 'البت', 'تذر', 'عبو', 'الجن', 'ردن', 'عاهم', 'الظالمين', 'تمني', 'أنها', 'امت', 'ختصا', 'كلوز', 'طاهر', 'نعيش', 'فطي', 'قتهم', 'نــي', 'ساسا', 'حبب', 'تقر', 'اضع', 'يلنت', 'سلوب', 'اراة', 'عذ', 'التواصل', 'شتاق', 'رضا', 'بأس', 'إنتي', 'عوو', 'لخلي', 'عده', 'لبح', 'ركب', 'تث', 'مآ', 'افات', 'تكت', 'لفتر', 'هوى', 'متني', 'دفة', 'لسن', 'قبر', 'رحة', 'كيل', 'كتو', 'تلها', 'مصد', 'أخي', 'نمو', 'مله', 'مسلس', 'إق', 'بنحبك', 'الري', 'بيك', 'سابا', 'رجول', 'ابه', 'مغني', 'الإق', 'شق', 'فري', 'عار', 'فظة', 'بقر', 'يره', 'جأ', 'لأهل', 'بتز', 'يكف', 'لى', 'أك', 'حلقة', 'قصة', 'تكن', 'لبدء', 'سهل', 'روحك']

# %% [markdown]
# # generating features for training documents ...

# %%
feature_sets = [(document_features(d, my_features), c) for (d, c) in train_data]

# %% [markdown]
# # training ...

# %%
classifier = nltk.NaiveBayesClassifier.train(feature_sets)
print('training is done')

# %% [markdown]
# # Most informative features

# %%
classifier.show_most_informative_features(40)

# %% [markdown]
# # generating features for test documents ...

# %%
test_features = [(document_features(d, my_features), c) for (d, c) in train_data]

# %%
print(test_features)

# %% [markdown]
# # classify test instances

# %%
ref_sets = collections.defaultdict(set)
test_sets = collections.defaultdict(set)

for i, (feats, label) in enumerate(test_features):
    ref_sets[label].add(i)
    observed = classifier.classify(feats)
    test_sets[observed].add(i)

# %% [markdown]
# # Results

# %%
print('accuracy: ', nltk.classify.accuracy(classifier, test_features))
print('pos precision: ', precision(ref_sets['pos'], test_sets['pos']))
print('pos recall:', recall(ref_sets['pos'], test_sets['pos']))
print('neg precision: ', precision(ref_sets['neg'], test_sets['neg']))
print('neg recall:', recall(ref_sets['neg'], test_sets['neg']))
print('neu precision: ', precision(ref_sets['neu'], test_sets['neu']))
print('neu recall:', recall(ref_sets['neu'], test_sets['neu']))
print('positive f-score:', f_measure(ref_sets['pos'], test_sets['pos']))
print('negative f-score:', f_measure(ref_sets['neg'], test_sets['neg']))
print('neutral f-score:', f_measure(ref_sets['neu'], test_sets['neu']))

# %%
accuracy:  0.7659671532846716
pos precision:  0.7375381485249237
pos recall: 0.8682634730538922
neg precision:  0.7790849673202614
neg recall: 0.7650834403080873
neu precision:  0.8063063063063063
neu recall: 0.6193771626297578
positive f-score: 0.7975797579757976
negative f-score: 0.772020725388601
neutral f-score: 0.700587084148728
